# %% [markdown]
# <a href="https://colab.research.google.com/github/programminghumanity/iphs200fall2020/blob/main/twitter_step2_parse_clean_20201130.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Twitter Step 2: Parse and Clean Tweets**
# By: Jon Chun
# 30 Nov 2020
#
# * Parse tweets into components (e.g. hashtags, emojis, etc)
# * Clean the main text of the tweets (e.g. lowercase, remove punct, etc)
#
# Reference:
#
# * https://www.freecodecamp.org/news/how-to-combine-multiple-csv-files-with-8-lines-of-code-265183e0854/

# %% [markdown]
# # **0. Setup Environment**

# %% [markdown]
# ## You will need to give permission for this Colab to link to your gdrive in the code cell below

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# !pwd
# Out:
# /gdrive

# %%
# SET working directory

dir_working = './MyDrive/courses/2020f_iphs200_programming_humanity/code/twint/'

# %%
# CUSTOMIZE: if you want your work and twitter datasets saved into a specific folder
#            beneath your gdrive root directory, define it below

# %cd $dir_working
# Out:
# /gdrive/MyDrive/courses/2020f_iphs200_programming_humanity/code/twint

# %%
# !pwd
# Out:
# /gdrive/MyDrive/courses/2020f_iphs200_programming_humanity/code/twint

# %%
# !ls -al *.csv
# Out:
# -rw------- 1 root root   986297 Dec  8 23:33 cleaned_tweets_combined_20201204-193123.csv
# -rw------- 1 root root   782295 Dec  4 19:31 tweets_combined_20201204-193111.csv
# -rw------- 1 root root   782295 Dec  4 19:31 tweets_combined_20201204-193123.csv
# -rw------- 1 root root    40893 Dec  4 19:57 tweets_ner_sa__20201204-195723.csv
# -rw------- 1 root root    40822 Dec  9 00:24 tweets_ner_sa__20201209-002453.csv
# -rw------- 1 root root  5665660 Dec  8 16:42 tweets_twint_stopthesteal__20201208-164240.csv
# -rw------- 1 root root 28209455 Dec  8 16:46 tweets_twint_stopthesteal__20201208-164638.csv
# -rw------- 1 root root   790248 Dec  4 19:29 tweets_twint_tesla__20201204-192926.csv
# -rw------- 1 root root   790257 Dec  5 14:18 tweets_twint_tesla__20201205-141801.csv

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.

# %%
import os
import re
import glob

# %%
# !pip install contractions
# Out:
# Collecting contractions
#   Downloading https://files.pythonhosted.org/packages/ce/ad/d1c685967945a04f8596128b15a1ab56c51488f53312e953341af6ff22d1/contractions-0.0.43-py2.py3-none-any.whl
# Collecting textsearch
#   Downloading https://files.pythonhosted.org/packages/42/a8/03407021f9555043de5492a2bd7a35c56cc03c2510092b5ec018cae1bbf1/textsearch-0.0.17-py2.py3-none-any.whl
# Collecting Unidecode
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
#      |████████████████████████████████| 245kB 9.9MB/s
# Collecting pyahocorasick
#   Downloading https://files.pythonhosted.org/packages/f4/9f/f0d8e8850e12829eea2e778f1c90e3c53a9a799b7f412082a5d21cd19ae1/pyahocorasick-1.4.0.tar.gz (312kB)
#      |████████████████████████████████| 317kB 19.8MB/s
# Building wheels for collected packages: pyahocorasick
#   Building wheel for pyahocorasick (setup.py) ... done
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.0-cp36-cp36m-linux_x86_64.whl size=81709 sha256=8f95cc83d7b1f17217b1e9eaa24fd690b55d27761badf521241cf4633b320785
#   Stored in directory: /root/.cache/pip/wheels/0a/90/61/87a55f5b459792fbb2b7ba6b31721b06ff5cf6bde541b40994
# Successfully built pyahocorasick
# Installing collected packages: Unidecode, pyahocorasick, textsearch, contractions
# Successfully installed Unidecode-1.1.1 contractions-0.0.43 pyahocorasick-1.4.0 textsearch-0.0.17

# %%
import contractions

# %% [markdown]
# # **1. Read in Combined Tweet Dataset File**

# %%
# !ls -al *.csv
# Out:
# -rw------- 1 root root   986297 Dec  8 23:33 cleaned_tweets_combined_20201204-193123.csv
# -rw------- 1 root root   782295 Dec  4 19:31 tweets_combined_20201204-193111.csv
# -rw------- 1 root root   782295 Dec  4 19:31 tweets_combined_20201204-193123.csv
# -rw------- 1 root root    40893 Dec  4 19:57 tweets_ner_sa__20201204-195723.csv
# -rw------- 1 root root    40822 Dec  9 00:24 tweets_ner_sa__20201209-002453.csv
# -rw------- 1 root root  5665660 Dec  8 16:42 tweets_twint_stopthesteal__20201208-164240.csv
# -rw------- 1 root root 28209455 Dec  8 16:46 tweets_twint_stopthesteal__20201208-164638.csv
# -rw------- 1 root root   790248 Dec  4 19:29 tweets_twint_tesla__20201204-192926.csv
# -rw------- 1 root root   790257 Dec  5 14:18 tweets_twint_tesla__20201205-141801.csv

# %%
# CONFIGURE: Set the 'file_name_all' to the name of the combined datafile with all the tweets
#            which should be listed in the previous code cell

file_name_all = 'tweets_combined_20201204-193123.csv'

# %%
combined_df = pd.read_csv(file_name_all, encoding='utf-8')
combined_df = combined_df.convert_dtypes()
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1591 entries, 0 to 1590
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1591 non-null   Int64
#  1   conversation_id  1591 non-null   Int64
#  2   created_at       1591 non-null   string
#  3   date             1591 non-null   string
#  4   time             1591 non-null   string
#  5   timezone         1591 non-null   Int64
#  6   user_id          1591 non-null   Int64
#  7   username         1591 non-null   string
#  8   name             1591 non-null   string
#  9   place            0 non-null      Int64
#  10  tweet            1591 non-null   string
#  11  language         1591 non-null   string
#  12  mentions         1591 non-null   string
#  13  urls             1591 non-null   string
#  14  photos           1591 non-null   string
#  15  replies_count    1591 non-null   Int64
#  16  retweets_count   1591 non-null   Int64
#  17  likes_count      1591 non-null   Int64
#  18  hashtags         1591 non-null   string
#  19  cashtags         1591 non-null   string
#  20  link             1591 non-null   string
#  21  retweet          1591 non-null   boolean
#  22  quote_url        62 non-null     string
#  23  video            1591 non-null   Int64
#  24  thumbnail        49 non-null     string
#  25  near             0 non-null      Int64
#  26  geo              0 non-null      Int64
#  27  source           0 non-null      Int64
#  28  user_rt_id       0 non-null      Int64
#  29  user_rt          0 non-null      Int64
#  30  retweet_id       0 non-null      Int64
#  31  reply_to         1591 non-null   string
#  32  retweet_date     0 non-null      Int64
#  33  translate        0 non-null      Int64
#  34  trans_src        0 non-null      Int64
#  35  trans_dest       0 non-null      Int64
# dtypes: Int64(19), boolean(1), string(16)
# memory usage: 467.8 KB

# %%
combined_df.shape
# Out:
# (1591, 36)

# %%
combined_df.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1334127507906314240  1333882505775050752  2020-12-02 13:29:19 UTC
# 1  1331075177262661633  1330843965613027329  2020-11-24 03:20:27 UTC
# 2  1330982572038500355  1330980211509186560  2020-11-23 21:12:28 UTC
# 3  1330206139385044999  1330179916587884544  2020-11-21 17:47:12 UTC
# 4  1330187635483140099  1330179916587884544  2020-11-21 16:33:40 UTC
#
#          date      time  timezone   user_id  username       name  place  \
# 0  2020-12-02  13:29:19  0         44196397  elonmusk  Elon Musk  <NA>
# 1  2020-11-24  03:20:27  0         44196397  elonmusk  Elon Musk  <NA>
# 2  2020-11-23  21:12:28  0         44196397  elonmusk  Elon Musk  <NA>
# 3  2020-11-21  17:47:12  0         44196397  elonmusk  Elon Musk  <NA>
# 4  2020-11-21  16:33:40  0         44196397  elonmusk  Elon Musk  <NA>
#
#                                                                                                                                                                                                                                           tweet  \
# 0  @Tesmanian_com Award accepted on behalf of the great people at Tesla, SpaceX, Neuralink &amp; Boring Co
# 1  @PPathole @Teslarati @TeslaRoadTrip We’re still far from simply video in, control out. The biggest game-changer, currently underway at Tesla, is 360 degree, high fps video for labeling, training &amp; inference.
# 2  @vincent13031925 @Tesla Wow
# 3  @heydave7 @philwhln Tesla is a vehicle for creating &amp; producing many useful products
# 4  @philwhln @heydave7 Because I am not an investor. Tesla is definitely not the only good company, but investing is not what I do. But I always put my own money into companies I help create, otherwise it’d be wrong to ask others to do so.
#
#   language mentions urls photos  replies_count  retweets_count  likes_count  \
# 0  en       []       []   []     313            284             8385
# 1  en       []       []   []     135            97              2542
# 2  und      []       []   []     790            367             19411
# 3  en       []       []   []     103            106             1941
# 4  en       []       []   []     130            145             2495
#
#   hashtags cashtags                                                     link  \
# 0  []       []       https://twitter.com/elonmusk/status/1334127507906314240
# 1  []       []       https://twitter.com/elonmusk/status/1331075177262661633
# 2  []       []       https://twitter.com/elonmusk/status/1330982572038500355
# 3  []       []       https://twitter.com/elonmusk/status/1330206139385044999
# 4  []       []       https://twitter.com/elonmusk/status/1330187635483140099
#
#    retweet quote_url  video thumbnail  near   geo  source  user_rt_id  \
# 0  False    <NA>      0      <NA>      <NA>  <NA>  <NA>    <NA>
# 1  False    <NA>      0      <NA>      <NA>  <NA>  <NA>    <NA>
# 2  False    <NA>      0      <NA>      <NA>  <NA>  <NA>    <NA>
# 3  False    <NA>      0      <NA>      <NA>  <NA>  <NA>    <NA>
# 4  False    <NA>      0      <NA>      <NA>  <NA>  <NA>    <NA>
#
#    user_rt  retweet_id  \
# 0  <NA>     <NA>
# 1  <NA>     <NA>
# 2  <NA>     <NA>
# 3  <NA>     <NA>
# 4  <NA>     <NA>
#
#                                                                                                                                                                                                                             reply_to  \
# 0  [{'screen_name': 'Tesmanian_com', 'name': 'Tesmanian.com', 'id': '1100520274200416256'}]
# 1  [{'screen_name': 'PPathole', 'name': 'Pranay Pathole', 'id': '1291945442'}, {'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': '1308211178'}, {'screen_name': 'TeslaRoadTrip', 'name': 'TeslaRoadTrip', 'id': '1182382878'}]
# 2  [{'screen_name': 'vincent13031925', 'name': 'Vincent 🚀\U0001f7e0', 'id': '1689516060'}, {'screen_name': 'Tesla', 'name': 'Tesla', 'id': '13298072'}]
# 3  [{'screen_name': 'heydave7', 'name': 'Dave Lee', 'id': '29893444'}, {'screen_name': 'philwhln', 'name': 'Phil Whelan 😷🇨🇦\U0001f995🚀', 'id': '13036132'}]
# 4  [{'screen_name': 'philwhln', 'name': 'Phil Whelan 😷🇨🇦\U0001f995🚀', 'id': '13036132'}, {'screen_name': 'heydave7', 'name': 'Dave Lee', 'id': '29893444'}]
#
#    retweet_date  translate  trans_src  trans_dest
# 0  <NA>          <NA>       <NA>       <NA>
# 1  <NA>          <NA>       <NA>       <NA>
# 2  <NA>          <NA>       <NA>       <NA>
# 3  <NA>          <NA>       <NA>       <NA>
# 4  <NA>          <NA>       <NA>       <NA>

# %% [markdown]
# # **2. Parse Tweets into Components**
#
# Your class assignment this semester had you manually clean tweets to reinforce your understanding of Python, RegEx and NLP using tweets. For the final class project, I encourage you to use text preprocessing libraries like 'preprocessor' illustrated below so you can focus on analysis and interpretation.
#
# Unfortunately, the 'preprocessor' library is relatively new and has no written documentation as of Nov 2020 (see: https://preprocessor.readthedocs.io/en/latest/). By experimenting and looking at code reversed engineering the key functionality you may want to use in the code blocks below.
#
# References:
#
# * https://github.com/s/preprocessor
# * https://towardsdatascience.com/basic-tweet-preprocessing-in-python-efd8360d529e

# %% [markdown]
# ## Python Library to clean tweets: preprocessor
#
# Cleans tweets, customizable filters
# * Input: string
# * Output: string
#
# Ref: https://github.com/s/preprocessor
#
# ```
# p.set_options(p.OPT.URL, p.OPT.EMOJI)
# p.clean('Preprocessor is #awesome 👍 https://github.com/s/preprocessor')
# 'Preprocessor is #awesome'
# ```
#
# Options are:
# ```
# Option Name	Option Short Code
# URL	p.OPT.URL
# Mention	p.OPT.MENTION
# Hashtag	p.OPT.HASHTAG
# Reserved Words	p.OPT.RESERVED
# Emoji	p.OPT.EMOJI
# Smiley	p.OPT.SMILEY
# Number	p.OPT.NUMBER
# ```
#
# The next few code blocks will show you how the library 'preprocessor' can clean, parse and tokenize tweets
#
# * More info at: https://github.com/s/preprocessor

# %%
# !pip install tweet-preprocessor
# Out:
# Collecting tweet-preprocessor
#   Downloading https://files.pythonhosted.org/packages/17/9d/71bd016a9edcef8860c607e531f30bd09b13103c7951ae73dd2bf174163c/tweet_preprocessor-0.6.0-py3-none-any.whl
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.6.0

# %%
import preprocessor as p

# %%
#install tweet-preprocessor to clean tweets
# https://towardsdatascience.com/twitter-sentiment-analysis-nlp-text-analytics-b7b296d71fce
# https://github.com/importdata/Twitter-Sentiment-Analysis/blob/master/Twitter_Sentiment_Analysis_Support_Vector_Classifier.ipynb

#set up punctuations we want to be replaced
REPLACE_NO_SPACE = re.compile("(\.)|(\;)|(\:)|(\!)|(\')|(\?)|(\,)|(\")|(\|)|(\()|(\))|(\[)|(\])|(\%)|(\$)|(\>)|(\<)|(\{)|(\})")
REPLACE_WITH_SPACE = re.compile("(<br\s/><br\s/?)|(-)|(/)|(:).")

def tweet_nopunct(astr):
  """input string is cleaned of punctuation and markup tags"""
  astr_clean = p.clean(astr)
  #remove puctuation
  astr_clean = REPLACE_NO_SPACE.sub("", astr_clean.lower()) # convert all tweets to lower cases
  astr_clean = REPLACE_WITH_SPACE.sub(" ", astr_clean)
  return astr_clean

# %%
# Test cleaning a tweet
 
# use 'p.set_options()' to filter out different types of tokens (e.g. URL, EMOJI, etc)
# if p.set_options() not called, clean will filter out everything but plain text
# if p.set_options() called, any p.OPT.x listed will be filtered out and unmentioned OPT will pass thru

# p.set_options(p.OPT.URL)
tweet_wpunct_str = p.clean('Preprocessor! is #awesome 👍 https://github.com/s/preprocessor')
print(tweet_wpunct_str)
# Out:
# Preprocessor! is

# %%
# Test cleaning a tweet with filters to remove tags and punctuation

tweet_wopunct_test = tweet_nopunct('Preprocessor! is #awesome 👍 https://github.com/s/preprocessor')
print(tweet_wopunct_test)
# Out:
# preprocessor is

# %%
def parseitem2list(api):
  """ Convert a preprocessor 'ParseItem' var into a Python list var """
  alist = []

  for i, val in enumerate(api):
    alist.append(val.match)
  
  return alist

# %%
def parse_tweet(tweet_str):
  """Parse the text of a tweet into sub-components and store in dict"""
  
  parsed_tweet_pi = p.parse(tweet_str)

  def parseitem2list(api):
    """ Convert a preprocessor 'ParseItem' var into a Python list var """
    alist = []

    for i, val in enumerate(api):
      alist.append(val.match)
    
    return alist  

  # convert our urls ParseItem to a standard Python list
  if (parsed_tweet_pi.urls):
    tweet_urls_ls = parseitem2list(parsed_tweet_pi.urls)
  else:
    tweet_urls_ls = []

  # convert our hashtags ParseItem to a standard Python list
  if (parsed_tweet_pi.hashtags):
    tweet_hashtags_ls = parseitem2list(parsed_tweet_pi.hashtags)
  else:
    tweet_hashtags_ls = []

  # convert our mentions ParseItem to a standard Python list
  if (parsed_tweet_pi.mentions):
    tweet_mentions_ls = parseitem2list(parsed_tweet_pi.mentions)
  else:
    tweet_mentions_ls = []

  # convert our emojis ParseItem to a standard Python list
  if (parsed_tweet_pi.emojis):
    tweet_emojis_ls = parseitem2list(parsed_tweet_pi.emojis)
  else:
    tweet_emojis_ls = []

  # convert our smileys ParseItem to a standard Python list
  if (parsed_tweet_pi.smileys):
    tweet_smileys_ls = parseitem2list(parsed_tweet_pi.smileys)
  else:
    tweet_smileys_ls = []

  # convert our numbers ParseItem to a standard Python list
  if (parsed_tweet_pi.numbers):
    tweet_numbers_ls = parseitem2list(parsed_tweet_pi.numbers)
  else:
    tweet_numbers_ls = []


  tweet_dt = {'urls': tweet_urls_ls, 
              'hashtags': tweet_hashtags_ls,
              'mentions': tweet_mentions_ls,
              'emojis': tweet_emojis_ls,
              'smileys': tweet_smileys_ls,
              'numbers': tweet_numbers_ls}

  return tweet_dt

# %%
# Test
atweet = '@bigfoot :o http://bigfoot.ai says FAV Preprocessor ;/ is #awesome 👍 https://github.com/s/preprocessor RT if you like this #kickarse'

parse_tweet(atweet) # ['emojis']
# Out:
# {'emojis': ['👍'],
#  'hashtags': ['#awesome', '#kickarse'],
#  'mentions': ['@bigfoot'],
#  'numbers': [],
#  'smileys': [':o', ';/ '],
#  'urls': ['http://bigfoot.ai', 'https://github.com/s/preprocessor']}

# %%
# Test
atweet = '@littlehand ;< http://littlehand.ai says FAV Preprocessor >:/ is #terrible 👍 https://github.com/s/preprocessor RT if you hate this #sucks'

parse_tweet(atweet)
# Out:
# {'emojis': ['👍'],
#  'hashtags': ['#terrible', '#sucks'],
#  'mentions': ['@littlehand'],
#  'numbers': [],
#  'smileys': [':/ '],
#  'urls': ['http://littlehand.ai', 'https://github.com/s/preprocessor']}

# %%
combined_df.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1334127507906314240  1333882505775050752  2020-12-02 13:29:19 UTC
# 1  1331075177262661633  1330843965613027329  2020-11-24 03:20:27 UTC
# 2  1330982572038500355  1330980211509186560  2020-11-23 21:12:28 UTC
# 3  1330206139385044999  1330179916587884544  2020-11-21 17:47:12 UTC
# 4  1330187635483140099  1330179916587884544  2020-11-21 16:33:40 UTC
#
#          date      time  timezone   user_id  username       name  place  \
# 0  2020-12-02  13:29:19  0         44196397  elonmusk  Elon Musk  <NA>
# 1  2020-11-24  03:20:27  0         44196397  elonmusk  Elon Musk  <NA>
# 2  2020-11-23  21:12:28  0         44196397  elonmusk  Elon Musk  <NA>
# 3  2020-11-21  17:47:12  0         44196397  elonmusk  Elon Musk  <NA>
# 4  2020-11-21  16:33:40  0         44196397  elonmusk  Elon Musk  <NA>
#
#                                                                                                                                                                                                                                           tweet  \
# 0  @Tesmanian_com Award accepted on behalf of the great people at Tesla, SpaceX, Neuralink &amp; Boring Co
# 1  @PPathole @Teslarati @TeslaRoadTrip We’re still far from simply video in, control out. The biggest game-changer, currently underway at Tesla, is 360 degree, high fps video for labeling, training &amp; inference.
# 2  @vincent13031925 @Tesla Wow
# 3  @heydave7 @philwhln Tesla is a vehicle for creating &amp; producing many useful products
# 4  @philwhln @heydave7 Because I am not an investor. Tesla is definitely not the only good company, but investing is not what I do. But I always put my own money into companies I help create, otherwise it’d be wrong to ask others to do so.
#
#   language mentions urls photos  replies_count  retweets_count  likes_count  \
# 0  en       []       []   []     313            284             8385
# 1  en       []       []   []     135            97              2542
# 2  und      []       []   []     790            367             19411
# 3  en       []       []   []     103            106             1941
# 4  en       []       []   []     130            145             2495
#
#   hashtags cashtags                                                     link  \
# 0  []       []       https://twitter.com/elonmusk/status/1334127507906314240
# 1  []       []       https://twitter.com/elonmusk/status/1331075177262661633
# 2  []       []       https://twitter.com/elonmusk/status/1330982572038500355
# 3  []       []       https://twitter.com/elonmusk/status/1330206139385044999
# 4  []       []       https://twitter.com/elonmusk/status/1330187635483140099
#
#    retweet quote_url  video thumbnail  near   geo  source  user_rt_id  \
# 0  False    <NA>      0      <NA>      <NA>  <NA>  <NA>    <NA>
# 1  False    <NA>      0      <NA>      <NA>  <NA>  <NA>    <NA>
# 2  False    <NA>      0      <NA>      <NA>  <NA>  <NA>    <NA>
# 3  False    <NA>      0      <NA>      <NA>  <NA>  <NA>    <NA>
# 4  False    <NA>      0      <NA>      <NA>  <NA>  <NA>    <NA>
#
#    user_rt  retweet_id  \
# 0  <NA>     <NA>
# 1  <NA>     <NA>
# 2  <NA>     <NA>
# 3  <NA>     <NA>
# 4  <NA>     <NA>
#
#                                                                                                                                                                                                                             reply_to  \
# 0  [{'screen_name': 'Tesmanian_com', 'name': 'Tesmanian.com', 'id': '1100520274200416256'}]
# 1  [{'screen_name': 'PPathole', 'name': 'Pranay Pathole', 'id': '1291945442'}, {'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': '1308211178'}, {'screen_name': 'TeslaRoadTrip', 'name': 'TeslaRoadTrip', 'id': '1182382878'}]
# 2  [{'screen_name': 'vincent13031925', 'name': 'Vincent 🚀\U0001f7e0', 'id': '1689516060'}, {'screen_name': 'Tesla', 'name': 'Tesla', 'id': '13298072'}]
# 3  [{'screen_name': 'heydave7', 'name': 'Dave Lee', 'id': '29893444'}, {'screen_name': 'philwhln', 'name': 'Phil Whelan 😷🇨🇦\U0001f995🚀', 'id': '13036132'}]
# 4  [{'screen_name': 'philwhln', 'name': 'Phil Whelan 😷🇨🇦\U0001f995🚀', 'id': '13036132'}, {'screen_name': 'heydave7', 'name': 'Dave Lee', 'id': '29893444'}]
#
#    retweet_date  translate  trans_src  trans_dest
# 0  <NA>          <NA>       <NA>       <NA>
# 1  <NA>          <NA>       <NA>       <NA>
# 2  <NA>          <NA>       <NA>       <NA>
# 3  <NA>          <NA>       <NA>       <NA>
# 4  <NA>          <NA>       <NA>       <NA>

# %%
combined_df.iloc[-100:]['tweet']
# Out:
# 1491    Tesla Supercharger network now energized from New York to LA, both coast + Texas! Approx 80% of US population covered.
# 1492    Tesla policy is to charge the same price (+ taxes &amp; shipping) everywhere in the world  http://t.co/cXOtokcBeG
# 1493    German govt reviews Tesla Model S fires. All due to high speed impacts, no injuries. Concludes: no defects, no recall  http://t.co/24iZzOSL3B
# 1494    Tesla Model S Consumer Reports customer satisfaction survey highest of any car on road at 99/100  http://t.co/PpuS01S2KN
# 1495    Tesla is also extending the Model S warranty to cover any fire damage even if due solely to a driver accident
# 1496    Why does a Tesla fire w no injury get more media headlines than 100,000 gas car fires that kill 100s of people per year?
# 1497    Mission of Tesla   http://t.co/UchbT5NZE3
# 1498    Tesla West Coast Supercharger network now energized. Travel from Vancouver to Tijuana in styel!  http://t.co/gTvV9egg3K
# 1499    Intense effort underway at Tesla to develop a practical autopilot system for Model S
# 1500    One of the first Tesla Supercharger stations in Europe is being built in Cinderella, Norway #KatieWoodencloak
# 1501    Oh yeah, well Tesla will study a plan to study the GM team that's studying Tesla, so there!  http://t.co/Gn41zsaRv8
# 1502    Woohoo, Tesla direct sales petition passed the 100k threshold! Thanks a lot to everyone that helped!!
# 1503    @arthurblake Tesla service can do coating or can be done by any auto glass coating company. My car is done on side &amp; rear
# 1504    @LisaRoutel The NY auto dealers lost in court, so now they are funding a bill in NY legislature to block Tesla
# 1505    Tesla pack swap vid still being edited (multiple camera angles). In meantime, this article contains a vid  http://t.co/lyzJy4k8Eu
# 1506    Tomorrow night: fastest gas pump in LA vs Tesla battery pack swap  http://t.co/QgZzggjIkq
# 1507    Battery pack swap works with all Tesla Model S cars, past and present. It was always there.
# 1508    @zatulsky Shai actually got the idea from a visit to Tesla. The idea is obvious (many things allow battery swap), but the technology is not.
# 1509    Video of battery pack swap will be posted to the Tesla website around 9:30pm, so those attending will see this first.
# 1510    Forgot to say one thing at Tesla annual shareholders meeting: just as my money was the first in, it will be the last out.
# 1511    Huge expansion of Tesla Supercharger network underway. Will cover LA to NY by end of year  http://t.co/MFKjBJzklc
# 1512    You Can Fit A Lot Of Kindergartners In A Tesla Model S - Houston Chronicle  http://t.co/iOZPxrx3sa
# 1513    Technically, I "got rich" from Zip2 &amp; PayPal w zero govt anything, then put 100% of that into SpaceX, Tesla &amp; SolarCity.
# 1514    Net of gas savings, a Tesla is $550 to $600/month with down payment taken care of by tax credits. Maybe less costly then it first seems.
# 1515    Me &amp; other private money funded Tesla for first 7 years, got IPO+ govt money for 3, now paid back. Yes, carbon tax would be a better way.
# 1516    Great article on Tesla-dealer battle by Leilani Munter (@CarbonFreeGirl), who lives in NC  http://t.co/pvEmE5pEVN
# 1517    Interview with @BloombergNews about Tesla and DOE loan gets into some of the details  http://t.co/xb0JVoPHNC
# 1518    Tesla wired the funds to repay the DOE loan today. Only US car company to have fully repaid govt  http://t.co/jxHW9YkvPz
# 1519    @RaimisJ Tesla software knits together Google Voice, Slacker, Gracenote &amp; others and streams over 3G (will be LTE later)
# 1520    There is a way for the Tesla Model S to be recharged throughout the country faster than you could fill a gas tank.
# 1521    @HowardReiter Totally agree. Tesla will circle back and do something cool for Roadsters next year.
# 1522    Just want to say thanks to customers &amp; investors that took a chance on Tesla through the long, dark night. We wouldn't be here without you.
# 1523    Tesla priority is electrification of cars, so priority is Model S, Model X, then mass market third gen vehicle &amp; truck
# 1524    Creating an autopilot for cars at Tesla is an important, but not yet top priority. Still a few years from production.
# 1525    Anyone interested in doing ultra hardcore vehicle engineering at Tesla, please apply!
# 1526    Chris Porritt from Aston Martin just joined as head of vehicle engineering at Tesla  http://t.co/MNUIWDxoXt
# 1527    @DouglasBullard @teslamotors Most people have never heard of Nikola Tesla. That will hopefully change over time.
# 1528    Tesla raises Model S resale value guarantee to highest in auto industry  http://t.co/l5LOXtyP33
# 1529    Time to up the ante (and fix some mistakes). Tesla announcement tomorrow.
# 1530    Auto Dealer Sterling McCall makes the case for Tesla direct sales in Texas  http://t.co/JcHETe0d2l
# 1531    @Tapp697 Thanks, important clarification. Tesla announcements are always about making product experience better. Market follows eventually.
# 1532    Announcement of new @TeslaMotors strategy tomorrow. Tesla owners will like this.
# 1533    Not all good news. Virginia DMV Commissioner just denied Tesla a dealer license, despite Hearing Officer being in favor.
# 1534    If you live in Texas and are pro Tesla, please vote in the @MyABJ opinion poll!  http://t.co/ozPdw6UzUo
# 1535    New York judge just ruled in favor Tesla, dismissing the legal attack by auto dealers to prevent direct sales!
# 1536    Yay for democracy! @latimes asks: Should Tesla Motors be able to sell directly to consumers?  http://t.co/IhSNht6bgx
# 1537    Just had Texas BBQ for lunch in Capitol Building. About to head to House Committee hearing to advocate for Tesla in TX.
# 1538    In TX to make the case for allowing Tesla to sell cars. Pls come to Capitol Room E2.014 at 1:30!  http://t.co/WR3WXE8SFe
# 1539    New Tesla red going down assembly line for the first time. We spent a lot of time on this color!  http://t.co/e7twjazWPx
# 1540    Sarah Palin calls Tesla a loser. Am deeply wounded.  http://t.co/eOGT80Ut4L  Btw, Model S warranty does cover "bricking".
# 1541    @sightalignment Hoping to open the Century City Tesla store this month. It is my neighborhood mall, so I'm there all the time.
# 1542    Am headed to TX next week to thank people personally for supporting Tesla. Please head to SB 1659 @ 8am tomorrow #TeslaTX
# 1543    Certainly true that many people believe that Tesla and SpaceX are powered by the #hhgttg Infinite Improbability Drive :)
# 1544    Today's Tesla announcement is actually the 2nd in a 5 part trilogy (love Douglas Adams)
# 1545    To be clear, Tesla is in California, so it is not April Fool's yet! Also, some may differ, but imo the Tues news is arguably more important.
# 1546    First profitable Q for Tesla thanks to awesome customers &amp; hard work by a super dedicated team  http://t.co/njumz2SDmx
# 1547    Thanks Bob “@BobMetcalfe: Tesla Takes on TX Dealer's Association (MA too) - Repeal anti-competitive dealer laws -  http://t.co/qbbBkGkvzC"
# 1548    If you support Tesla in Texas, please contact your state Senate or House member. Free enterprise!  http://t.co/BoaveKd4NZ
# 1549    Auto dealers in Texas are trying to stop Tesla. Would appreciate your help in fighting for what's right  http://t.co/5T4pH7u5fX
# 1550    Review of Tesla Model S by @RoadandTrack. Good article w minor errors addressed in reader comments  http://t.co/qfQDWL96wQ
# 1551    Craig Venter talks about flu vaccines and the Tesla Model S. Gesundheit!  http://t.co/nt2etVUjDq
# 1552    Using Über to order a Tesla Model S @SXSW with @shervin and @travisk  http://t.co/69H47lMjBw
# 1553    Check out Model S at Tesla Austin Gallery at The Domain opening today! I will stop by this eve and tomorrow morning.
# 1554    Minnesota auto dealers tried to pass legislation to block Tesla stores. Bill was just defeated in Senate. Thanks MN!
# 1555    @batasrki Yeah, Top Gear pretended the Tesla Roadster ran out of charge and they had to push it home. Logs showed 50 miles range left.
# 1556    @tomleykis Thanks Tom! Support of real Tesla customers like yourself who drive the car every day is v much appreciated.
# 1557    Tesla data logging is only turned on with explicit written permission from customers, but after Top Gear BS, we always keep it on for media.
# 1558    Tesla blog coming soon detailing what actually happened on Broder's NYTimes "range test". Also lining up other journalists to do same drive.
# 1559    NYTimes article about Tesla range in cold is fake. Vehicle logs tell true story that he didn't actually charge to max &amp; took a long detour.
# 1560    Maybe already under control, but Tesla &amp; SpaceX are happy to help with the 787 lithium ion batteries.
# 1561    CA's Death Valley is #1 again! Tesla hot weather testing was done there. Model S was fine but gas tow truck overheated.
# 1562    Thanks! “@ev: Have driven a Tesla Model S 50 miles now. It's clearly the iPhone of cars—by far the best car ever made."
# 1563    Tesla articles 30 mins apart: "This Stock is Screaming Buy"  http://t.co/jb9DCw4s and "This Stock Could Get DESTROYED"  http://t.co/dqxTK4LJ
# 1564    Tesla was just approved for a full Class 1 Massachusetts Auto Sales License by a vote of 4 to 1. Much appreciated!
# 1565    Congrats to @dmetcalf for being the first to drive a Tesla Model S over 400 miles on a single charge!
# 1566    Am happy to report that Tesla was narrowly cash flow positive last week. Continued improvement expected through year end.
# 1567    Mass. judge denies auto dealers' demand to kill our little Tesla store. Yay, justice prevails!   http://t.co/MqnNYScE
# 1568    Sounds like Consumer Reports had a good experience with the Tesla Model S  http://t.co/CT3dgHbh
# 1569    V proud of Tesla team for completing 1000th Model S body. More cars made this month than entire rest of year  http://t.co/k8XWaEth
# 1570    Just wrote a blog piece about Tesla stores  http://t.co/4Ebs4HIw
# 1571    An update about Tesla   http://t.co/A8hQXVNI
# 1572    The Tesla Supercharger will over time allow you to travel anywhere on pure sunlight for free  http://t.co/DEscYLLH
# 1573    Tesla made 100 vehicle bodies this week for the first time. Really proud of the team! Pic of S/N 396:  http://t.co/fZzbUIjn
# 1574    Tesla Supercharger unveiling event set for Sept 24. It will feel like alien spaceships landed at highway rest stops.
# 1575    Tesla Model S driven 285 miles from Vegas to the beach in LA on a single charge by @motortrend  http://t.co/8YvO1tsz
# 1576    Glad to contribute to the Tesla museum and will do more in the future. He was a great man.  http://t.co/NR2QNiax
# 1577    @DJjodes Would love to make a Tesla supertruck with crazy torque, dynamic air suspension and corners like its on rails. That'd be sweet...
# 1578    @walalm Yes, my absolute goal w Tesla has always been mass market electric cars. Will finally get there with Gen3 program.
# 1579    After 2008 meltdown, vacation for me just meant email with a view, but SpaceX &amp; Tesla are now strong enough that I can make it real (yay!!)
# 1580    Major Tesla milestone: All crash testing is complete for 5* (max) safety rating. Cars can now be built for sale to public!
# 1581    Meant to say: prizes for first 10 who do 400 miles in Tesla w/o recharging, not nonstop, which would require diapers :)
# 1582    Wow, a Tesla owner in Europe just passed 200,000 km while racing his Roadster!  http://t.co/ZYV4h85O
# 1583    The President of Serbia came by our booth at the Geneva Motor Show and talked about Nikola Tesla  http://t.co/KIhxc0TF
# 1584    Tesla Model X is 3rd most searched term on Google, right after purple squirrel. Damn you squirrel!  http://t.co/jP9H5XrB
# 1585    Tesla Model X video   http://t.co/pjcaicOc
# 1586    That's not just paranoia (a healthy trait at times). Tesla really is under massive attack by short sellers  http://t.co/PUxAOOm2
# 1587    Will communicate better in the future. Too many people want us to fail and are willing to twist any bit of news against Tesla.
# 1588    A Tesla Roadster just passed the 100,000 mile mark for the first time and still has over 200 miles of range.
# 1589    The exec conf room at Tesla used to be called Denali, but I decided to move a few letters around. Seemed more apt :)  http://t.co/Raq5UaR6
# 1590    Hacked my Tesla charge connector on a small island in the rain last night #whatcouldpossiblygowrong
# Name: tweet, dtype: string

# %%
parse_tweet(combined_df.iloc[1015]['tweet'])
# Out:
# {'emojis': ['🐻', '🚘'],
#  'hashtags': [],
#  'mentions': ['@incentives101', '@Jason', '@Tesla'],
#  'numbers': [],
#  'smileys': [],
#  'urls': []}

# %%
parse_tweet(combined_df.iloc[1500]['tweet'])['hashtags']
# Out:
# ['#KatieWoodencloak']

# %%
# Split out identifable tweet subcomponents into separate columns before cleaning them further below

combined_df['hashtags'] = combined_df['tweet'].apply(lambda astr : parse_tweet(astr)['hashtags'])
combined_df['mentions'] = combined_df['tweet'].apply(lambda astr : parse_tweet(astr)['mentions'])
combined_df['urls'] = combined_df['tweet'].apply(lambda astr : parse_tweet(astr)['urls'])

# %%
# Split out identifable tweet subcomponents into separate columns before cleaning them further below

combined_df['emojis'] = combined_df['tweet'].apply(lambda astr : parse_tweet(astr)['emojis'])
combined_df['smileys'] = combined_df['tweet'].apply(lambda astr : parse_tweet(astr)['smileys'])
combined_df['numbers'] = combined_df['tweet'].apply(lambda astr : parse_tweet(astr)['numbers'])

# %%
combined_df['tweet'][1010:1015]
# Out:
# 1010    @FredericLambert No such thing as a “full refresh” at Tesla or even a model year. Our cars are partially upgraded every month as soon as a new subsystem is ready for production. There is no cadence.
# 1011    The physics of how Tesla achieved best safety of any cars ever tested. Note, when vehicle weight is taken into account, order is more like X,S, then 3, but they are all very close.
# 1012    Tesla owner shows how well ultrawhite seats hold up after 25,000 miles. The black &amp; white interior is def best imo.  https://t.co/vWQ8X8JHYF
# 1013    @AsbjornLD @martinengwicht @Jason @Tesla Two — one for 👽 👾 millions of years from now and one for you
# 1014    @martinengwicht @Jason @Tesla Yes
# Name: tweet, dtype: string

# %%
combined_df[1010:1015]
# Out:
#                        id      conversation_id               created_at  \
# 1010  1049716203676037122  1049707571102306304  2018-10-09 17:40:20 UTC
# 1011  1049324111367815169  1049324111367815169  2018-10-08 15:42:18 UTC
# 1012  1049045561792294912  1049045561792294912  2018-10-07 21:15:26 UTC
# 1013  1048692170377506817  1048466642194259968  2018-10-06 21:51:11 UTC
# 1014  1048690159875588096  1048466642194259968  2018-10-06 21:43:12 UTC
#
#             date      time  timezone   user_id  username       name  place  \
# 1010  2018-10-09  17:40:20  0         44196397  elonmusk  Elon Musk  <NA>
# 1011  2018-10-08  15:42:18  0         44196397  elonmusk  Elon Musk  <NA>
# 1012  2018-10-07  21:15:26  0         44196397  elonmusk  Elon Musk  <NA>
# 1013  2018-10-06  21:51:11  0         44196397  elonmusk  Elon Musk  <NA>
# 1014  2018-10-06  21:43:12  0         44196397  elonmusk  Elon Musk  <NA>
#
#                                                                                                                                                                                                        tweet  \
# 1010  @FredericLambert No such thing as a “full refresh” at Tesla or even a model year. Our cars are partially upgraded every month as soon as a new subsystem is ready for production. There is no cadence.
# 1011  The physics of how Tesla achieved best safety of any cars ever tested. Note, when vehicle weight is taken into account, order is more like X,S, then 3, but they are all very close.
# 1012  Tesla owner shows how well ultrawhite seats hold up after 25,000 miles. The black &amp; white interior is def best imo.  https://t.co/vWQ8X8JHYF
# 1013  @AsbjornLD @martinengwicht @Jason @Tesla Two — one for 👽 👾 millions of years from now and one for you
# 1014  @martinengwicht @Jason @Tesla Yes
#
#      language                                       mentions  \
# 1010  en       [@FredericLambert]
# 1011  en       []
# 1012  en       []
# 1013  en       [@AsbjornLD, @martinengwicht, @Jason, @Tesla]
# 1014  und      [@martinengwicht, @Jason, @Tesla]
#
#                            urls photos  replies_count  retweets_count  \
# 1010  []                         []     112            129
# 1011  []                         []     906            3047
# 1012  [https://t.co/vWQ8X8JHYF]  []     460            602
# 1013  []                         []     27             30
# 1014  []                         []     14             15
#
#       likes_count hashtags cashtags  \
# 1010  1229         []       []
# 1011  27124        []       []
# 1012  10058        []       []
# 1013  617          []       []
# 1014  578          []       []
#
#                                                          link  retweet  \
# 1010  https://twitter.com/elonmusk/status/1049716203676037122  False
# 1011  https://twitter.com/elonmusk/status/1049324111367815169  False
# 1012  https://twitter.com/elonmusk/status/1049045561792294912  False
# 1013  https://twitter.com/elonmusk/status/1048692170377506817  False
# 1014  https://twitter.com/elonmusk/status/1048690159875588096  False
#
#                                                  quote_url  video thumbnail  \
# 1010  <NA>                                                  0      <NA>
# 1011  https://twitter.com/Tesla/status/1049284924321087488  0      <NA>
# 1012  <NA>                                                  0      <NA>
# 1013  <NA>                                                  0      <NA>
# 1014  <NA>                                                  0      <NA>
#
#       near   geo  source  user_rt_id  user_rt  retweet_id  \
# 1010  <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 1011  <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 1012  <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 1013  <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 1014  <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
#
#                                                                                                                                                                                                                               reply_to  \
# 1010  [{'screen_name': 'FredericLambert', 'name': 'Fred Lambert', 'id': '38253449'}]
# 1011  []
# 1012  []
# 1013  [{'screen_name': 'MartinEngwicht', 'name': 'Starship Trooper', 'id': '1252353732672716800'}, {'screen_name': 'Jason', 'name': 'jason@calacanis.com', 'id': '3840'}, {'screen_name': 'Tesla', 'name': 'Tesla', 'id': '13298072'}]
# 1014  [{'screen_name': 'MartinEngwicht', 'name': 'Starship Trooper', 'id': '1252353732672716800'}, {'screen_name': 'Jason', 'name': 'jason@calacanis.com', 'id': '3840'}, {'screen_name': 'Tesla', 'name': 'Tesla', 'id': '13298072'}]
#
#       retweet_date  translate  trans_src  trans_dest  emojis smileys  \
# 1010  <NA>          <NA>       <NA>       <NA>        []      []
# 1011  <NA>          <NA>       <NA>       <NA>        []      []
# 1012  <NA>          <NA>       <NA>       <NA>        []      []
# 1013  <NA>          <NA>       <NA>       <NA>        [👽, 👾]  []
# 1014  <NA>          <NA>       <NA>       <NA>        []      []
#
#         numbers
# 1010  []
# 1011  [ 3]
# 1012  [ 25,000]
# 1013  []
# 1014  []

# %%
# Convert columns to more specific dtype

combined_df = combined_df.convert_dtypes() # astype({'tweet':'str'})
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1591 entries, 0 to 1590
# Data columns (total 39 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1591 non-null   Int64
#  1   conversation_id  1591 non-null   Int64
#  2   created_at       1591 non-null   string
#  3   date             1591 non-null   string
#  4   time             1591 non-null   string
#  5   timezone         1591 non-null   Int64
#  6   user_id          1591 non-null   Int64
#  7   username         1591 non-null   string
#  8   name             1591 non-null   string
#  9   place            0 non-null      Int64
#  10  tweet            1591 non-null   string
#  11  language         1591 non-null   string
#  12  mentions         1591 non-null   object
#  13  urls             1591 non-null   object
#  14  photos           1591 non-null   string
#  15  replies_count    1591 non-null   Int64
#  16  retweets_count   1591 non-null   Int64
#  17  likes_count      1591 non-null   Int64
#  18  hashtags         1591 non-null   object
#  19  cashtags         1591 non-null   string
#  20  link             1591 non-null   string
#  21  retweet          1591 non-null   boolean
#  22  quote_url        62 non-null     string
#  23  video            1591 non-null   Int64
#  24  thumbnail        49 non-null     string
#  25  near             0 non-null      Int64
#  26  geo              0 non-null      Int64
#  27  source           0 non-null      Int64
#  28  user_rt_id       0 non-null      Int64
#  29  user_rt          0 non-null      Int64
#  30  retweet_id       0 non-null      Int64
#  31  reply_to         1591 non-null   string
#  32  retweet_date     0 non-null      Int64
#  33  translate        0 non-null      Int64
#  34  trans_src        0 non-null      Int64
#  35  trans_dest       0 non-null      Int64
#  36  emojis           1591 non-null   object
#  37  smileys          1591 non-null   object
#  38  numbers          1591 non-null   object
# dtypes: Int64(19), boolean(1), object(6), string(13)
# memory usage: 505.1+ KB

# %%
# test

pd.to_datetime('2020-11-08')
# Out:
# Timestamp('2020-11-08 00:00:00')

# %%
# Still should convert created_at to datetime type
# all_my_tweets_df = all_my_tweets_df.astype({"topic":str, "id":int, "username":str})
combined_df['created_at'] = pd.to_datetime(combined_df['created_at'], errors='ignore', yearfirst=True, infer_datetime_format=True) # = all_my_tweets_df['tweet_dt'].to_datetime()

# %%
# df['Date']= pd.to_datetime(df['Date'])
# combined_df['tweet_dt'] = pd.to_datetime(combined_df['tweet_dt'], errors='coerce')

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1591 entries, 0 to 1590
# Data columns (total 39 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1591 non-null   Int64
#  1   conversation_id  1591 non-null   Int64
#  2   created_at       1591 non-null   datetime64[ns, UTC]
#  3   date             1591 non-null   string
#  4   time             1591 non-null   string
#  5   timezone         1591 non-null   Int64
#  6   user_id          1591 non-null   Int64
#  7   username         1591 non-null   string
#  8   name             1591 non-null   string
#  9   place            0 non-null      Int64
#  10  tweet            1591 non-null   string
#  11  language         1591 non-null   string
#  12  mentions         1591 non-null   object
#  13  urls             1591 non-null   object
#  14  photos           1591 non-null   string
#  15  replies_count    1591 non-null   Int64
#  16  retweets_count   1591 non-null   Int64
#  17  likes_count      1591 non-null   Int64
#  18  hashtags         1591 non-null   object
#  19  cashtags         1591 non-null   string
#  20  link             1591 non-null   string
#  21  retweet          1591 non-null   boolean
#  22  quote_url        62 non-null     string
#  23  video            1591 non-null   Int64
#  24  thumbnail        49 non-null     string
#  25  near             0 non-null      Int64
#  26  geo              0 non-null      Int64
#  27  source           0 non-null      Int64
#  28  user_rt_id       0 non-null      Int64
#  29  user_rt          0 non-null      Int64
#  30  retweet_id       0 non-null      Int64
#  31  reply_to         1591 non-null   string
#  32  retweet_date     0 non-null      Int64
#  33  translate        0 non-null      Int64
#  34  trans_src        0 non-null      Int64
#  35  trans_dest       0 non-null      Int64
#  36  emojis           1591 non-null   object
#  37  smileys          1591 non-null   object
#  38  numbers          1591 non-null   object
# dtypes: Int64(19), boolean(1), datetime64[ns, UTC](1), object(6), string(12)
# memory usage: 505.1+ KB

# %%
# Test to see if all columns have at least one value
print(combined_df[combined_df.isna().all(axis=1)])
# Out:
# Empty DataFrame
# Columns: [id, conversation_id, created_at, date, time, timezone, user_id, username, name, place, tweet, language, mentions, urls, photos, replies_count, retweets_count, likes_count, hashtags, cashtags, link, retweet, quote_url, video, thumbnail, near, geo, source, user_rt_id, user_rt, retweet_id, reply_to, retweet_date, translate, trans_src, trans_dest, emojis, smileys, numbers]
# Index: []

# %%
# drop any completely null tweets

combined_df.dropna(how='all', axis=0, inplace=True)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1590
# Data columns (total 39 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1591 non-null   Int64
#  1   conversation_id  1591 non-null   Int64
#  2   created_at       1591 non-null   datetime64[ns, UTC]
#  3   date             1591 non-null   string
#  4   time             1591 non-null   string
#  5   timezone         1591 non-null   Int64
#  6   user_id          1591 non-null   Int64
#  7   username         1591 non-null   string
#  8   name             1591 non-null   string
#  9   place            0 non-null      Int64
#  10  tweet            1591 non-null   string
#  11  language         1591 non-null   string
#  12  mentions         1591 non-null   object
#  13  urls             1591 non-null   object
#  14  photos           1591 non-null   string
#  15  replies_count    1591 non-null   Int64
#  16  retweets_count   1591 non-null   Int64
#  17  likes_count      1591 non-null   Int64
#  18  hashtags         1591 non-null   object
#  19  cashtags         1591 non-null   string
#  20  link             1591 non-null   string
#  21  retweet          1591 non-null   boolean
#  22  quote_url        62 non-null     string
#  23  video            1591 non-null   Int64
#  24  thumbnail        49 non-null     string
#  25  near             0 non-null      Int64
#  26  geo              0 non-null      Int64
#  27  source           0 non-null      Int64
#  28  user_rt_id       0 non-null      Int64
#  29  user_rt          0 non-null      Int64
#  30  retweet_id       0 non-null      Int64
#  31  reply_to         1591 non-null   string
#  32  retweet_date     0 non-null      Int64
#  33  translate        0 non-null      Int64
#  34  trans_src        0 non-null      Int64
#  35  trans_dest       0 non-null      Int64
#  36  emojis           1591 non-null   object
#  37  smileys          1591 non-null   object
#  38  numbers          1591 non-null   object
# dtypes: Int64(19), boolean(1), datetime64[ns, UTC](1), object(6), string(12)
# memory usage: 517.4+ KB

# %%
# check if any columns are null

# print(combined_df[combined_df.isna().any(axis=1)])

# %%
combined_df.head()
# Out:
#                     id      conversation_id                created_at  \
# 0  1334127507906314240  1333882505775050752 2020-12-02 13:29:19+00:00
# 1  1331075177262661633  1330843965613027329 2020-11-24 03:20:27+00:00
# 2  1330982572038500355  1330980211509186560 2020-11-23 21:12:28+00:00
# 3  1330206139385044999  1330179916587884544 2020-11-21 17:47:12+00:00
# 4  1330187635483140099  1330179916587884544 2020-11-21 16:33:40+00:00
#
#          date      time  timezone   user_id  username       name  place  \
# 0  2020-12-02  13:29:19  0         44196397  elonmusk  Elon Musk  <NA>
# 1  2020-11-24  03:20:27  0         44196397  elonmusk  Elon Musk  <NA>
# 2  2020-11-23  21:12:28  0         44196397  elonmusk  Elon Musk  <NA>
# 3  2020-11-21  17:47:12  0         44196397  elonmusk  Elon Musk  <NA>
# 4  2020-11-21  16:33:40  0         44196397  elonmusk  Elon Musk  <NA>
#
#                                                                                                                                                                                                                                           tweet  \
# 0  @Tesmanian_com Award accepted on behalf of the great people at Tesla, SpaceX, Neuralink &amp; Boring Co
# 1  @PPathole @Teslarati @TeslaRoadTrip We’re still far from simply video in, control out. The biggest game-changer, currently underway at Tesla, is 360 degree, high fps video for labeling, training &amp; inference.
# 2  @vincent13031925 @Tesla Wow
# 3  @heydave7 @philwhln Tesla is a vehicle for creating &amp; producing many useful products
# 4  @philwhln @heydave7 Because I am not an investor. Tesla is definitely not the only good company, but investing is not what I do. But I always put my own money into companies I help create, otherwise it’d be wrong to ask others to do so.
#
#   language                                 mentions urls photos  \
# 0  en       [@Tesmanian_com]                         []   []
# 1  en       [@PPathole, @Teslarati, @TeslaRoadTrip]  []   []
# 2  und      [@vincent13031925, @Tesla]               []   []
# 3  en       [@heydave7, @philwhln]                   []   []
# 4  en       [@philwhln, @heydave7]                   []   []
#
#    replies_count  retweets_count  likes_count hashtags cashtags  \
# 0  313            284             8385         []       []
# 1  135            97              2542         []       []
# 2  790            367             19411        []       []
# 3  103            106             1941         []       []
# 4  130            145             2495         []       []
#
#                                                       link  retweet quote_url  \
# 0  https://twitter.com/elonmusk/status/1334127507906314240  False    <NA>
# 1  https://twitter.com/elonmusk/status/1331075177262661633  False    <NA>
# 2  https://twitter.com/elonmusk/status/1330982572038500355  False    <NA>
# 3  https://twitter.com/elonmusk/status/1330206139385044999  False    <NA>
# 4  https://twitter.com/elonmusk/status/1330187635483140099  False    <NA>
#
#    video thumbnail  near   geo  source  user_rt_id  user_rt  retweet_id  \
# 0  0      <NA>      <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 1  0      <NA>      <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 2  0      <NA>      <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 3  0      <NA>      <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 4  0      <NA>      <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
#
#                                                                                                                                                                                                                             reply_to  \
# 0  [{'screen_name': 'Tesmanian_com', 'name': 'Tesmanian.com', 'id': '1100520274200416256'}]
# 1  [{'screen_name': 'PPathole', 'name': 'Pranay Pathole', 'id': '1291945442'}, {'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': '1308211178'}, {'screen_name': 'TeslaRoadTrip', 'name': 'TeslaRoadTrip', 'id': '1182382878'}]
# 2  [{'screen_name': 'vincent13031925', 'name': 'Vincent 🚀\U0001f7e0', 'id': '1689516060'}, {'screen_name': 'Tesla', 'name': 'Tesla', 'id': '13298072'}]
# 3  [{'screen_name': 'heydave7', 'name': 'Dave Lee', 'id': '29893444'}, {'screen_name': 'philwhln', 'name': 'Phil Whelan 😷🇨🇦\U0001f995🚀', 'id': '13036132'}]
# 4  [{'screen_name': 'philwhln', 'name': 'Phil Whelan 😷🇨🇦\U0001f995🚀', 'id': '13036132'}, {'screen_name': 'heydave7', 'name': 'Dave Lee', 'id': '29893444'}]
#
#    retweet_date  translate  trans_src  trans_dest emojis smileys numbers
# 0  <NA>          <NA>       <NA>       <NA>        []     []      []
# 1  <NA>          <NA>       <NA>       <NA>        []     []      [ 360]
# 2  <NA>          <NA>       <NA>       <NA>        []     []      []
# 3  <NA>          <NA>       <NA>       <NA>        []     []      []
# 4  <NA>          <NA>       <NA>       <NA>        []     []      []

# %%
# Create clean tweet from original tweet text

# expand contractions
combined_df['tweet_clean'] = combined_df['tweet'].apply(lambda astr : contractions.fix(astr))

# remove punctuation
combined_df['tweet_clean'] = combined_df['tweet_clean'].apply(lambda astr : tweet_nopunct(astr))

# collapse multiple-whitespaces to one whitespace
combined_df['tweet_clean'] = combined_df['tweet_clean'].apply(lambda astr : ' '.join(astr.split()))

# all_my_tweets_df['tweet_clean'] = all_my_tweets_df['tweet'].apply(lambda astr : p.clean(astr))
# ERR: all_my_tweets_df['tweet_clean'] = all_my_tweets_df['tweet'].str.apply(p.clean(astr)

# %%
combined_df['tweet_clean'][:40]
# Out:
# 0     award accepted on behalf of the great people at tesla spacex neuralink &amp boring co
# 1     we are still far from simply video in control out the biggest game changer currently underway at tesla is degree high fps video for labeling training &amp inference
# 2     wow
# 3     tesla is a vehicle for creating &amp producing many useful products
# 4     because i am not an investor tesla is definitely not the only good company but investing is not what i do but i always put my own money into companies i help create otherwise it would be wrong to ask others to do so
# 5     andrej is awesome but it should be said that we have a very talented autopilot ai team at tesla too much credit comes to me &amp andrej
# 6     safety is our primary design goal
# 7     a lot of my brain space is spent dealing with both units
# 8     the only publicly traded stock i own is tesla
# 9     tesla holiday software release is
# 10    curevac moderna &amp a few others tesla makes the machine curevac uses to go from known gene sequence to trillions of lipid coated mrna strands
# 11    happy to see this
# 12    i do expect this to become an important product for the world but probably not financially material for tesla
# 13    tesla makes the rna bioreactor that can make vaccines cures curevac has version in use version is under development
# 14    thanks to a lot of great autopilot ai hardware &amp software engineers at tesla
# 15    wait until you see what cybertruck will do
# 16    enough already on my plate &amp teslas maybe one day will do a prototype those are relatively easy volume production with high reliability &amp low cost &amp passing all regulations is x harder
# 17    tesla autopilot ai team
# 18    faraday invented the electric motor tesla the commutator free three phase ac induction motor in other words a useful electric motor
# 19    maxwell was amazing should have more recognition tesla motors inc was almost called faraday as it took until late 2005 to buy the trademark from a guy who had had it since
# 20    i put in my last money even though i thought we would still fail but it was either that or certain death for tesla extremely difficult to raise money for an electric car startup considered super quirky back then while stalwarts like gm &amp chrysler were going bankrupt
# 21    tesla texas team is making great progress giga texas factory will be an asskicker
# 22    tesla should make catgirl robots
# 23    tesla team has done great work
# 24    yes very helpful thanks all beta testers
# 25    now that tesla fsd beta is out in limited release fsd price new or upgrade will go up by ~2k on monday
# 26    as soon as we complete testing &amp regulators approve so many different traffic signs rules &amp languages around world not to mention driving on left side of road also a long &amp challenging road lies ahead getting to high s reliability way beyond human
# 27    yes
# 28    haha
# 29    not intentional we just wanted to show that you could theoretically convert the entire us vehicle fleet to electric using only the lithium in nevada a single state tesla will do lithium mining only as needed we also found a way to extract lithium using nacl table salt
# 30    congratulations
# 31    it is still there but focus is vegas &amp prufrock our new tunneling machine
# 32    for sure
# 33    maybe a month or so some finishing touches need to be done on the stations
# 34    we simplified this a lot it is basically just teslas in tunnels at this point which is way more profound than it sounds
# 35    tesla fsd computers dual socs function like twin engines on planes they each run different neural nets so we do get full use of tops but there are enough nets running on each to allow the car to drive to safety if one soc or engine in this analogy fails
# 36    glad jen is safe
# 37    there are sketchy edits to tesla wiki that whitewash eberhards problems glorify his role pretty odd i was interim ceo co ceo from july michael marks was co ceo for ~q4 &amp zeev drori for q1 to ~q3 after q3 financing round bust no choice but to be ceo
# 38    when eberhard was fired from the tesla ceo role in mid for providing false information to me &amp the board no one left with him that says it all
# 39    spacex tesla metallurgy &amp new materials team is next level
# Name: tweet_clean, dtype: object

# %%
combined_df.head()
# Out:
#                     id      conversation_id                created_at  \
# 0  1334127507906314240  1333882505775050752 2020-12-02 13:29:19+00:00
# 1  1331075177262661633  1330843965613027329 2020-11-24 03:20:27+00:00
# 2  1330982572038500355  1330980211509186560 2020-11-23 21:12:28+00:00
# 3  1330206139385044999  1330179916587884544 2020-11-21 17:47:12+00:00
# 4  1330187635483140099  1330179916587884544 2020-11-21 16:33:40+00:00
#
#          date      time  timezone   user_id  username       name  place  \
# 0  2020-12-02  13:29:19  0         44196397  elonmusk  Elon Musk  <NA>
# 1  2020-11-24  03:20:27  0         44196397  elonmusk  Elon Musk  <NA>
# 2  2020-11-23  21:12:28  0         44196397  elonmusk  Elon Musk  <NA>
# 3  2020-11-21  17:47:12  0         44196397  elonmusk  Elon Musk  <NA>
# 4  2020-11-21  16:33:40  0         44196397  elonmusk  Elon Musk  <NA>
#
#                                                                                                                                                                                                                                           tweet  \
# 0  @Tesmanian_com Award accepted on behalf of the great people at Tesla, SpaceX, Neuralink &amp; Boring Co
# 1  @PPathole @Teslarati @TeslaRoadTrip We’re still far from simply video in, control out. The biggest game-changer, currently underway at Tesla, is 360 degree, high fps video for labeling, training &amp; inference.
# 2  @vincent13031925 @Tesla Wow
# 3  @heydave7 @philwhln Tesla is a vehicle for creating &amp; producing many useful products
# 4  @philwhln @heydave7 Because I am not an investor. Tesla is definitely not the only good company, but investing is not what I do. But I always put my own money into companies I help create, otherwise it’d be wrong to ask others to do so.
#
#   language                                 mentions urls photos  \
# 0  en       [@Tesmanian_com]                         []   []
# 1  en       [@PPathole, @Teslarati, @TeslaRoadTrip]  []   []
# 2  und      [@vincent13031925, @Tesla]               []   []
# 3  en       [@heydave7, @philwhln]                   []   []
# 4  en       [@philwhln, @heydave7]                   []   []
#
#    replies_count  retweets_count  likes_count hashtags cashtags  \
# 0  313            284             8385         []       []
# 1  135            97              2542         []       []
# 2  790            367             19411        []       []
# 3  103            106             1941         []       []
# 4  130            145             2495         []       []
#
#                                                       link  retweet quote_url  \
# 0  https://twitter.com/elonmusk/status/1334127507906314240  False    <NA>
# 1  https://twitter.com/elonmusk/status/1331075177262661633  False    <NA>
# 2  https://twitter.com/elonmusk/status/1330982572038500355  False    <NA>
# 3  https://twitter.com/elonmusk/status/1330206139385044999  False    <NA>
# 4  https://twitter.com/elonmusk/status/1330187635483140099  False    <NA>
#
#    video thumbnail  near   geo  source  user_rt_id  user_rt  retweet_id  \
# 0  0      <NA>      <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 1  0      <NA>      <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 2  0      <NA>      <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 3  0      <NA>      <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
# 4  0      <NA>      <NA>  <NA>  <NA>    <NA>        <NA>     <NA>
#
#                                                                                                                                                                                                                             reply_to  \
# 0  [{'screen_name': 'Tesmanian_com', 'name': 'Tesmanian.com', 'id': '1100520274200416256'}]
# 1  [{'screen_name': 'PPathole', 'name': 'Pranay Pathole', 'id': '1291945442'}, {'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': '1308211178'}, {'screen_name': 'TeslaRoadTrip', 'name': 'TeslaRoadTrip', 'id': '1182382878'}]
# 2  [{'screen_name': 'vincent13031925', 'name': 'Vincent 🚀\U0001f7e0', 'id': '1689516060'}, {'screen_name': 'Tesla', 'name': 'Tesla', 'id': '13298072'}]
# 3  [{'screen_name': 'heydave7', 'name': 'Dave Lee', 'id': '29893444'}, {'screen_name': 'philwhln', 'name': 'Phil Whelan 😷🇨🇦\U0001f995🚀', 'id': '13036132'}]
# 4  [{'screen_name': 'philwhln', 'name': 'Phil Whelan 😷🇨🇦\U0001f995🚀', 'id': '13036132'}, {'screen_name': 'heydave7', 'name': 'Dave Lee', 'id': '29893444'}]
#
#    retweet_date  translate  trans_src  trans_dest emojis smileys numbers  \
# 0  <NA>          <NA>       <NA>       <NA>        []     []      []
# 1  <NA>          <NA>       <NA>       <NA>        []     []      [ 360]
# 2  <NA>          <NA>       <NA>       <NA>        []     []      []
# 3  <NA>          <NA>       <NA>       <NA>        []     []      []
# 4  <NA>          <NA>       <NA>       <NA>        []     []      []
#
#                                                                                                                                                                                                                tweet_clean
# 0  award accepted on behalf of the great people at tesla spacex neuralink &amp boring co
# 1  we are still far from simply video in control out the biggest game changer currently underway at tesla is degree high fps video for labeling training &amp inference
# 2  wow
# 3  tesla is a vehicle for creating &amp producing many useful products
# 4  because i am not an investor tesla is definitely not the only good company but investing is not what i do but i always put my own money into companies i help create otherwise it would be wrong to ask others to do so

# %% [markdown]
# # **3. Write Parsed & Cleaned Tweets to datafile.csv**

# %%
# Create unique output filename using current datetime stamp

file_name_cleaned = ('cleaned_' + file_name_all.split('.')[0] + '.csv') # 'tweets_combined_20201201-012404.csv'
print(file_name_cleaned)

combined_df.to_csv(file_name_cleaned)
# Out:
# cleaned_tweets_combined_20201204-193123.csv

# %%
# !ls -al cleaned_*
# Out:
# -rw------- 1 root root 986297 Dec  9 19:36 cleaned_tweets_combined_20201204-193123.csv

# %%
# !head -5 $file_name_cleaned
# Out:
# ,id,conversation_id,created_at,date,time,timezone,user_id,username,name,place,tweet,language,mentions,urls,photos,replies_count,retweets_count,likes_count,hashtags,cashtags,link,retweet,quote_url,video,thumbnail,near,geo,source,user_rt_id,user_rt,retweet_id,reply_to,retweet_date,translate,trans_src,trans_dest,emojis,smileys,numbers,tweet_clean
# 0,1334127507906314240,1333882505775050752,2020-12-02 13:29:19+00:00,2020-12-02,13:29:19,0,44196397,elonmusk,Elon Musk,,"@Tesmanian_com Award accepted on behalf of the great people at Tesla, SpaceX, Neuralink &amp; Boring Co",en,['@Tesmanian_com'],[],[],313,284,8385,[],[],https://twitter.com/elonmusk/status/1334127507906314240,False,,0,,,,,,,,"[{'screen_name': 'Tesmanian_com', 'name': 'Tesmanian.com', 'id': '1100520274200416256'}]",,,,,[],[],[],award accepted on behalf of the great people at tesla spacex neuralink &amp boring co
# 1,1331075177262661633,1330843965613027329,2020-11-24 03:20:27+00:00,2020-11-24,03:20:27,0,44196397,elonmusk,Elon Musk,,"@PPathole @Teslarati @TeslaRoadTrip We’re still far from simply video in, control out. The biggest game-changer, currently underway at Tesla, is 360 degree, high fps video for labeling, training &amp; inference.",en,"['@PPathole', '@Teslarati', '@TeslaRoadTrip']",[],[],135,97,2542,[],[],https://twitter.com/elonmusk/status/1331075177262661633,False,,0,,,,,,,,"[{'screen_name': 'PPathole', 'name': 'Pranay Pathole', 'id': '1291945442'}, {'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': '1308211178'}, {'screen_name': 'TeslaRoadTrip', 'name': 'TeslaRoadTrip', 'id': '1182382878'}]",,,,,[],[],[' 360'],we are still far from simply video in control out the biggest game changer currently underway at tesla is degree high fps video for labeling training &amp inference
# 2,1330982572038500355,1330980211509186560,2020-11-23 21:12:28+00:00,2020-11-23,21:12:28,0,44196397,elonmusk,Elon Musk,,@vincent13031925 @Tesla Wow,und,"['@vincent13031925', '@Tesla']",[],[],790,367,19411,[],[],https://twitter.com/elonmusk/status/1330982572038500355,False,,0,,,,,,,,"[{'screen_name': 'vincent13031925', 'name': 'Vincent 🚀\U0001f7e0', 'id': '1689516060'}, {'screen_name': 'Tesla', 'name': 'Tesla', 'id': '13298072'}]",,,,,[],[],[],wow
# 3,1330206139385044999,1330179916587884544,2020-11-21 17:47:12+00:00,2020-11-21,17:47:12,0,44196397,elonmusk,Elon Musk,,@heydave7 @philwhln Tesla is a vehicle for creating &amp; producing many useful products,en,"['@heydave7', '@philwhln']",[],[],103,106,1941,[],[],https://twitter.com/elonmusk/status/1330206139385044999,False,,0,,,,,,,,"[{'screen_name': 'heydave7', 'name': 'Dave Lee', 'id': '29893444'}, {'screen_name': 'philwhln', 'name': 'Phil Whelan 😷🇨🇦\U0001f995🚀', 'id': '13036132'}]",,,,,[],[],[],tesla is a vehicle for creating &amp producing many useful products

# %% [markdown]
# # **4. Write Plain Text of Tweets for Traditional Text Analytics**

# %%
import time

# %%
# Create a filename of search results in a file with the name contained a unique timestamp
timestr = time.strftime("%Y%m%d-%H%M%S")
file_name_plaintext = f"tweets_plaintext_{timestr}.txt"

print(file_name_plaintext)
# Out:
# tweets_plaintext_20201209-193656.txt

# %%
# Write all tweets combined into one big file

combined_df.to_csv(file_name_plaintext, columns=['tweet_clean'], index=False, header=False, encoding='utf-8')

# %%
# Write a copy of the plaintext tweets with lines in reversed order
#   so the oldest tweets are first. This is reversed file is the one
#   you should use to visualize any timeseries like voyant-tools.org
#   which assumes the oldest tweets/datapoints are the begin on the
#   first line of a file and plot them left/oldest to right/newest on
#   the x-axis of time series visualizations.

# Create a reverse filename of search results in a file with the name contained a unique timestamp
timestr = time.strftime("%Y%m%d-%H%M%S")
file_name_plaintext_rev = f"tweets_plaintext_rev_{timestr}.txt"

print(file_name_plaintext_rev)
# Out:
# tweets_plaintext_rev_20201209-193707.txt

# %%
# Create a 'reversed' order of the plaintext file using 
#   simple UNIX command line utilities

# !tac $file_name_plaintext > $file_name_plaintext_rev

# %%
# Check to make sure both the regular and the reversed row order plaintext tweetfiles
#   exists and are the same size

# !ls -al tweets_plaintext_*
# Out:
# -rw------- 1 root root 148261 Dec  5 14:59 tweets_plaintext_20201205-145558.txt
# -rw------- 1 root root 148263 Dec  8 23:33 tweets_plaintext_20201208-233325.txt
# -rw------- 1 root root 148263 Dec  9 19:37 tweets_plaintext_20201209-193656.txt
# -rw------- 1 root root 148263 Dec  8 23:37 tweets_plaintext_rev_20201208-233326.txt
# -rw------- 1 root root 148263 Dec  9 19:37 tweets_plaintext_rev_20201209-193707.txt

# %%
# Check that the first 5 lines of the regular plaintext tweetfile...

# !head -n 5 $file_name_plaintext
# Out:
# award accepted on behalf of the great people at tesla spacex neuralink &amp boring co
# we are still far from simply video in control out the biggest game changer currently underway at tesla is degree high fps video for labeling training &amp inference
# wow
# tesla is a vehicle for creating &amp producing many useful products
# because i am not an investor tesla is definitely not the only good company but investing is not what i do but i always put my own money into companies i help create otherwise it would be wrong to ask others to do so

# %%
# ...match the last 5 lines of the reversed plaintext tweetfile

# !tail -n 5 $file_name_plaintext_rev
# Out:
# because i am not an investor tesla is definitely not the only good company but investing is not what i do but i always put my own money into companies i help create otherwise it would be wrong to ask others to do so
# tesla is a vehicle for creating &amp producing many useful products
# wow
# we are still far from simply video in control out the biggest game changer currently underway at tesla is degree high fps video for labeling training &amp inference
# award accepted on behalf of the great people at tesla spacex neuralink &amp boring co

# %%
# Check that the last 5 lines of the regular plaintext tweetfile...

# !tail -n 5 $file_name_plaintext
# Out:
# that is not just paranoia a healthy trait at times tesla really is under massive attack by short sellers
# will communicate better in the future too many people want us to fail and are willing to twist any bit of news against tesla
# a tesla roadster just passed the mile mark for the first time and still has over miles of range
# the exec conf room at tesla used to be called denali but i decided to move a few letters around seemed more apt
# hacked my tesla charge connector on a small island in the rain last night

# %%
# ...match the first 5 lines of the reversed plaintext tweetfile

# !head -n 5 $file_name_plaintext_rev
# Out:
# hacked my tesla charge connector on a small island in the rain last night
# the exec conf room at tesla used to be called denali but i decided to move a few letters around seemed more apt
# a tesla roadster just passed the mile mark for the first time and still has over miles of range
# will communicate better in the future too many people want us to fail and are willing to twist any bit of news against tesla
# that is not just paranoia a healthy trait at times tesla really is under massive attack by short sellers

# %%
# !head -n 10 $file_name_plaintext
# Out:
# award accepted on behalf of the great people at tesla spacex neuralink &amp boring co
# we are still far from simply video in control out the biggest game changer currently underway at tesla is degree high fps video for labeling training &amp inference
# wow
# tesla is a vehicle for creating &amp producing many useful products
# because i am not an investor tesla is definitely not the only good company but investing is not what i do but i always put my own money into companies i help create otherwise it would be wrong to ask others to do so
# andrej is awesome but it should be said that we have a very talented autopilot ai team at tesla too much credit comes to me &amp andrej
# safety is our primary design goal
# a lot of my brain space is spent dealing with both units
# the only publicly traded stock i own is tesla
# tesla holiday software release is

# %%
# !ls -al tweets_plaintext_*.txt
# Out:
# -rw------- 1 root root 148261 Dec  5 14:59 tweets_plaintext_20201205-145558.txt
# -rw------- 1 root root 148263 Dec  8 23:33 tweets_plaintext_20201208-233325.txt
# -rw------- 1 root root 148263 Dec  9 19:37 tweets_plaintext_20201209-193656.txt
# -rw------- 1 root root 148263 Dec  8 23:37 tweets_plaintext_rev_20201208-233326.txt
# -rw------- 1 root root 148263 Dec  9 19:37 tweets_plaintext_rev_20201209-193707.txt

# %%
# Add a period to the end of every tweet in the _rev_ file for 
#   NLP tasks that expect text to have been split into 
#   setences (e.g. each tweet on one line is a sentence ending with '.') 
#   like voyant-tools.org

# !ls *.txt
# Out:
# requirements.txt
# tweets_combined_20201204-193111_manifest.txt
# tweets_combined_20201204-193123_manifest.txt
# tweets_plaintext_20201205-145558.txt
# tweets_plaintext_20201208-233325.txt
# tweets_plaintext_20201209-193656.txt
# tweets_plaintext_rev_20201208-233326.txt
# tweets_plaintext_rev_20201209-193707.txt

# %%
# !awk '{ print $0, "." }' tweets_plaintext_rev_20201209-193707.txt >> tweets_plaintext_rev_periods_20201209-193707.txt

# %%
# !head -n 5 tweets_plaintext_rev_periods_20201209-193707.txt
# Out:
# hacked my tesla charge connector on a small island in the rain last night .
# the exec conf room at tesla used to be called denali but i decided to move a few letters around seemed more apt .
# a tesla roadster just passed the mile mark for the first time and still has over miles of range .
# will communicate better in the future too many people want us to fail and are willing to twist any bit of news against tesla .
# that is not just paranoia a healthy trait at times tesla really is under massive attack by short sellers .

# %%
tweets_plaintext_rev_20201209-193707.txt
# Out:
# requirements.txt
# tweets_combined_20201204-193111_manifest.txt
# tweets_combined_20201204-193123_manifest.txt
# tweets_plaintext_20201205-145558.txt
# tweets_plaintext_20201208-233325.txt
# tweets_plaintext_20201209-193656.txt
# tweets_plaintext_rev_20201208-233326.txt
# tweets_plaintext_rev_20201209-193707.txt
# tweets_plaintext_rev_periods_20201209-193707.txt

# %%
# Optional: Uncomment to force a download of the reversed plaintext tweet file

print('tweets_plaintext_rev_periods_20201209-193707.txt')

from google.colab import files
files.download('tweets_plaintext_rev_periods_20201209-193707.txt')
# Out:
# tweets_plaintext_rev_periods_20201209-193707.txt

# %%
# If the previous 4 cell block show confirm the reversed file is correct
#   download the file

# !gsutil -q -m cp $file_name_plaintext_rev $dir_working

# NOTE: the *_rev file will be in the ./twint/ subdirectory

# !cp $file_name_plaintext_rev $dir_working # "/content/drive/My Drive/"

# %%
# !man awk
# Out:
# AWK(1POSIX)                POSIX Programmer's Manual               AWK(1POSIX)
#
# G
#        This  manual  page is part of the POSIX Programmer's Manual.  The Linux
#        implementation of this interface may differ (consult the  corresponding
#        Linux  manual page for details of Linux behavior), or the interface may
#        not be implemented on Linux.
#
# E
#        awk — pattern scanning and processing language
#
# S
# ]
#
# ]...
# ]
#
# N
# k  programming
# k
#        program is a sequence of patterns and corresponding actions. When input
#        is read that matches a pattern, the action associated with that pattern
#        is carried out.
#
#        Input shall be interpreted as a sequence  of  records.  By  default,  a
#        record  is  a  line,  less  its  terminating <newline>, but this can be
# S built-in variable. Each record of  input  shall
#        be  matched  in turn against each pattern in the program. For each pat‐
#        tern matched, the associated action shall be executed.
#
# k utility shall interpret each input  record  as  a  sequence  of
#        fields  where, by default, a field is a string of non-<blank> non-<new‐
#        line> characters. This default <blank> and  <newline>  field  delimiter
# g
# k utility shall denote the first field in  a  record  $1,
#        the  second  $2,  and  so  on.  The symbol $0 shall refer to the entire
#        record; setting any other field causes the re-evaluation of $0. Assign‐
# F built-
#        in variable.
#
# S
# k utility  shall  conform  to  the  Base  Definitions  volume  of
# s.
#
#        The following options shall be supported:
#
# g
#                  Define the input field separator. This option shall be equiv‐
#                  alent to:
#
# g
#
# g  are  both
# S assignment resulting
# g is processed in command line  order  or  is
# g.  See the descrip‐
# S built-in variable, and how it is used, in  the
#                  EXTENDED DESCRIPTION section.
#
# e
# k
# ' shall denote the  standard  input.
#                  If  multiple instances of this option are specified, the con‐
# e  in  the  order
# k program can
#                  alternatively be specified in the command line  as  a  single
#                  argument.
#
# t
# t argument is
# t  operand.  The  specified
# k
# N patterns
#                  (if  any).  Multiple occurrences of this option can be speci‐
#                  fied.
#
# S
#        The following operands shall be supported:
#
# k  shall
# k program. The application shall supply
# k.  If the text
# k shall interpret the text as
#                  if it did.
#
# t can  be  inter‐
#                  mixed:
#
# e      A  pathname of a file that contains the input to be
#                            read, which is matched against the set of  patterns
# e operands are specified,
# ',  the  standard  input
#                            shall be used.
#
# t
#                            An  operand  that  begins  with  an <underscore> or
#                            alphabetic character from  the  portable  character
#                            set  (see  the table in the Base Definitions volume
# r
# t),  followed  by a sequence of underscores, dig‐
#                            its, and alphabetics from  the  portable  character
# ' character, shall specify a
#                            variable assignment rather than  a  pathname.   The
# ' represent the name of an
# k reserved  word
# r) the behavior is undefined. The char‐
#                            acters following the <equals-sign> shall be  inter‐
# k program pre‐
# ')  charac‐
# r), except that
#                            if the last character is an unescaped  <backslash>,
#                            it  shall  be  interpreted as a literal <backslash>
#                            rather than as the first character of the  sequence
# ".   The variable shall be assigned the value of
# G token and,  if  appropriate,  shall  be
# n
# k), the  variable  shall  also  be  assigned  its
#                            numeric  value. Each such variable assignment shall
#                            occur just prior to the processing of the following
# e,  if any. Thus, an assignment before the first
# N
#                            actions  (if  any),  while  an assignment after the
# D
# e arguments,
#                            assignments shall be executed before processing the
#                            standard input.
#
# N
# e operands are speci‐
# e option-argument  is
# k program contains no
# k program, standard
# k shall exit with a
#        return status of zero.
#
# S
# k program from any of the following sources  shall
#        be text files:
#
# e  operands or their equivalents, achieved by modifying the
# C
#
# e operands
#
# e function
#
# S is set to a value other  than  a  <newline>  or
#        not,  for these files, implementations shall support records terminated
#        with the specified separator up to {LINE_MAX}  bytes  and  may  support
#        longer records.
#
# e  is  specified,  the application shall ensure that the
# e option-arguments are text files and
#        their concatenation, in the same order as they appear in the arguments,
# k program.
#
# S
# k:
#
# G      Provide a default value for  the  internationalization  vari‐
#                  ables  that are unset or null. (See the Base Definitions vol‐
# ‐
# s  for  the  precedence of internationalization variables
#                  used to determine the values of locale categories.)
#
# L    If set to a non-empty string value, override  the  values  of
#                  all the other internationalization variables.
#
# E
#                  Determine  the locale for the behavior of ranges, equivalence
#                  classes, and multi-character collating elements within  regu‐
#                  lar expressions and in comparisons of string values.
#
# E  Determine  the  locale for the interpretation of sequences of
#                  bytes of text data as characters (for example, single-byte as
#                  opposed  to  multi-byte  characters  in  arguments  and input
#                  files), the behavior  of  character  classes  within  regular
#                  expressions, the identification of characters as letters, and
#                  the mapping of uppercase and  lowercase  characters  for  the
# r functions.
#
# S
#                  Determine the locale that should be used to affect the format
#                  and contents  of  diagnostic  messages  written  to  standard
#                  error.
#
# C
#                  Determine  the radix character used when interpreting numeric
#                  input, performing conversions between numeric and string val‐
#                  ues, and formatting numeric output. Regardless of locale, the
#                  <period> character (the decimal-point character of the  POSIX
#                  locale) is the decimal-point character recognized in process‐
# k programs (including assignments in command line argu‐
#                  ments).
#
# H   Determine the location of message catalogs for the processing
# S.
#
# H      Determine the search path when looking for commands  executed
# r), or input and output pipes; see the Base Def‐
# ‐
# s.
#
# k
# N.
#
# S
#        Default.
#
# T
# k program.
#
# R
#        The standard error shall be used only for diagnostic messages.
#
# S
# k program.
#
# N
# e
# k program is composed of pairs of the form:
#
# n }
#
#        Either the pattern or the action (including the enclosing brace charac‐
#        ters) can be omitted.
#
#        A missing pattern shall match any record of input, and a missing action
#        shall be equivalent to:
#
# }
#
# k program shall start by first executing the actions
# N patterns in the order they occur in the pro‐
# e operand (or standard input if no files were speci‐
#        fied)  shall be processed in turn by reading data from the file until a
#        record separator is seen (<newline> by default). Before the first  ref‐
#        erence to a field in the record is evaluated, the record shall be split
# s,  using  the
# S that was current at the time the record was read. Each pat‐
#        tern in the program then shall be evaluated in the order of occurrence,
#        and  the  action  associated with each pattern that matches the current
#        record executed. The action for a matching pattern  shall  be  executed
#        before  evaluating subsequent patterns. Finally, the actions associated
# D patterns shall be executed in the order they occur in  the
#        program.
#
# k
# s.  In the
#        following table, valid expression operations are given in  groups  from
#        highest  precedence  first to lowest precedence last, with equal-prece‐
#        dence operators grouped between horizontal lines. In expression evalua‐
#        tion, where the grammar is formally ambiguous, higher precedence opera‐
#        tors shall be evaluated before lower precedence operators. In this  ta‐
# 3  represent any expression, while
#        lvalue represents any entity that can be assigned to (that is,  on  the
#        left  side  of  an assignment operator).  The precise syntax of expres‐
# r.
#
# k
#
#    ┌─────────────────────┬─────────────────────────┬────────────────┬──────────────┐
# y │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r    │N/A           │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r                │Field reference          │String          │N/A           │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
#    │lvalue ++            │Post-increment           │Numeric         │N/A           │
#    │lvalue −−            │Post-decrement           │Numeric         │N/A           │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
#    │++ lvalue            │Pre-increment            │Numeric         │N/A           │
#    │−− lvalue            │Pre-decrement            │Numeric         │N/A           │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r          │Exponentiation           │Numeric         │Right         │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r               │Logical not              │Numeric         │N/A           │
# r               │Unary plus               │Numeric         │N/A           │
# r               │Unary minus              │Numeric         │N/A           │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r          │Multiplication           │Numeric         │Left          │
# r          │Division                 │Numeric         │Left          │
# r          │Modulus                  │Numeric         │Left          │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r          │Addition                 │Numeric         │Left          │
# r          │Subtraction              │Numeric         │Left          │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r            │String concatenation     │String          │Left          │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r          │Less than                │Numeric         │None          │
# r         │Less than or equal to    │Numeric         │None          │
# r         │Not equal to             │Numeric         │None          │
# r         │Equal to                 │Numeric         │None          │
# r          │Greater than             │Numeric         │None          │
# r         │Greater than or equal to │Numeric         │None          │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r          │ERE match                │Numeric         │None          │
# r         │ERE non-match            │Numeric         │None          │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r in array        │Array membership         │Numeric         │Left          │
# y   │Multi-dimension array    │Numeric         │Left          │
#    │                     │membership               │                │              │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r         │Logical AND              │Numeric         │Left          │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r         │Logical OR               │Numeric         │Left          │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# 3│Conditional expression   │Type of selected│Right         │
# 3  │              │
#    ├─────────────────────┼─────────────────────────┼────────────────┼──────────────┤
# r       │Exponentiation assignment│Numeric         │Right         │
# r       │Modulus assignment       │Numeric         │Right         │
# r       │Multiplication assignment│Numeric         │Right         │
# r       │Division assignment      │Numeric         │Right         │
# r       │Addition assignment      │Numeric         │Right         │
# r       │Subtraction assignment   │Numeric         │Right         │
# r    │Right         │
#    └─────────────────────┴─────────────────────────┴────────────────┴──────────────┘
#        Each expression shall have either a string value, a numeric  value,  or
#        both.  Except  as stated for specific contexts, the value of an expres‐
#        sion shall be implicitly converted to the type needed for  the  context
#        in  which  it  is  used. A string value shall be converted to a numeric
#        value either by the equivalent of  the  following  calls  to  functions
#        defined by the ISO C standard:
#
# ;
# e);
#
# e rep‐
#        resentation as follows:
#
#               The input string is decomposed into two parts: an initial,  pos‐
#               sibly empty, sequence of white-space characters (as specified by
# e()) and a subject sequence  interpreted  as  a  floating-
#               point constant.
#
# ' or
# ' sign, then a non-empty sequence of  digits  optionally  con‐
#               taining  a <period>, then an optional exponent part. An exponent
# ', followed by an optional sign,  fol‐
#               lowed by one or more decimal digits.
#
#               The  sequence  starting  with  the  first  digit or the <period>
#               (whichever occurs first) is interpreted as a  floating  constant
#               of  the  C  language,  and  if  neither  an  exponent part nor a
#               <period> appears, a <period> is assumed to follow the last digit
#               in the string. If the subject sequence begins with a minus-sign,
#               the value resulting from the conversion is negated.
#
#        A numeric value that is exactly equal to the value of an  integer  (see
# d) shall be con‐
# f  function
# t argument and the
# r argument.  Any
#        other numeric value shall be converted to a string by the equivalent of
# T
# t argument and the numeric value being converted as the first
# r argument. The result of the conversion is unspecified  if
# T is not a floating-point format specification. This
#        volume of POSIX.1‐2008 specifies no explicit conversions  between  num‐
#        bers  and strings. An application can force an expression to be treated
#        as a number by adding zero to it, or can force it to be  treated  as  a
# ") to it.
#
# g if it comes from
#        one of the following:
#
#         1. Field variables
#
# e() function
#
# E
#
# V array elements
#
# N array elements
#
# t() function
#
#         7. A command line variable assignment
#
#         8. Variable assignment from another numeric string variable
#
#        and an implementation-dependent condition corresponding to either  case
#        (a) or (b) below is met.
#
#         a. After the equivalent of the following calls to functions defined by
# d   would   differ    from
# e,  and any characters before the terminating null char‐
# d would be <blank> characters:
#
# ;
# ;
# ;
#
#         b. After all the following conversions have been applied, the  result‐
# R token as
# r:
#
#            --  All leading and trailing <blank> characters are discarded.
#
# ', it is discarded.
#
#            --  Each occurrence of the decimal point character from the current
#                locale is changed to a <period>.
# g shall be the value
# d() call. In case (b) if  the  first
# g shall be
# R token;  oth‐
# g shall be the numeric
# R token. Whether or  not  a  string  is  a
# g  shall  be relevant only in contexts where that term is
#        used in this section.
#
#        When an expression is used in a Boolean context, if it  has  a  numeric
#        value,  a  value  of zero shall be treated as false and any other value
#        shall be treated as true. Otherwise, a string value of the null  string
#        shall be treated as false and any other value shall be treated as true.
#        A Boolean context shall be one of the following:
#
#         *  The first subexpression of a conditional expression
#
#         *  An expression operated on by logical NOT, logical AND,  or  logical
#            OR
#
# r statement
#
# f statement
#
# e
#            statement
#
#         *  An expression used as a pattern (as in Overall Program Structure)
#
#        All arithmetic shall follow the semantics of floating-point  arithmetic
# d
# d).
#
#        The value of the expression:
#
# 2
#
#        shall be equivalent to the value returned by the ISO C  standard  func‐
#        tion call:
#
# 2)
#
#        The expression:
#
# r
#
#        shall be equivalent to the ISO C standard expression:
#
# r)
#
#        except  that  lvalue  shall  be  evaluated  only once. The value of the
#        expression:
#
# 2
#
#        shall be equivalent to the value returned by the ISO C  standard  func‐
#        tion call:
#
# 2)
#
#        The expression:
#
# r
#
#        shall be equivalent to the ISO C standard expression:
#
# r)
#
#        except that lvalue shall be evaluated only once.
#
#        Variables and fields shall be set by the assignment statement:
#
# n
#
# n shall determine the resulting variable type.
# ",
# ")  all of which shall produce a numeric
#        result. The left-hand side of an assignment and the target of increment
#        and  decrement operators can be one of a variable, an array with index,
#        or a field selector.
#
# k language supplies arrays that are used for storing  numbers  or
#        strings.   Arrays  need not be declared. They shall initially be empty,
#        and their sizes shall change dynamically. The  subscripts,  or  element
#        identifiers,  are  strings, providing a type of associative array capa‐
#        bility. An array name followed by a subscript  within  square  brackets
#        can be used as an lvalue and thus as an expression, as described in the
# r.  Unsubscripted array names can be  used  in  only
#        the following contexts:
#
#         *  A parameter in a function definition or function call
#
# n as specified in
# r); if the name used in this context is  not
#            an array name, the behavior is undefined
#
# x  shall  consist of one or more <comma>-separated
#        expressions, similar to the way in which multi-dimensional  arrays  are
# k arrays are really
#        one-dimensional, such a <comma>-separated list shall be converted to  a
#        single  string  by  concatenating  the  string  values  of the separate
# P
#        variable. Thus, the following two index operations shall be equivalent:
#
# ]
#
# ]
#
# x used with
# n operator, which tests for  the
#        existence  of  a particular array element, shall not cause that element
#        to exist. Any other reference to  a  nonexistent  array  element  shall
#        automatically create it.
#
# " operators)
#        shall be made numerically if both  operands  are  numeric,  if  one  is
#        numeric  and  the other has a string value that is a numeric string, or
#        if one is numeric and the other has the  uninitialized  value.   Other‐
#        wise,  operands  shall be converted to strings as required and a string
#        comparison shall be made using the locale-specific collation  sequence.
#        The  value  of  the comparison expression shall be 1 if the relation is
#        true, or 0 if the relation is false.
#
# s
# k program by referencing them.  With  the
# s), they are
#        not explicitly declared. Function parameter names shall be local to the
#        function; all other variable names shall be global. The same name shall
#        not be used as both a function parameter name and  as  the  name  of  a
# k variable. The same name shall not be used
#        both as a variable name with global scope and as the name  of  a  func‐
#        tion.  The  same name shall not be used within the same scope both as a
#        scalar variable and as an array.   Uninitialized  variables,  including
#        scalar  variables,  array  elements, and field variables, shall have an
#        uninitialized value. An uninitialized value shall have both  a  numeric
#        value  of  zero  and  a string value of the empty string. Evaluation of
#        variables with an uninitialized value, to  either  string  or  numeric,
#        shall be determined by the context in which they are used.
#
# ' followed by a number or
# n  evalu‐
#        ating  to  anything  other  than a non-negative integer is unspecified;
#        uninitialized variables or string  values  need  not  be  converted  to
#        numeric  values  in this context. New field variables can be created by
#        assigning a value to them. References to nonexistent fields  (that  is,
# F), shall evaluate to the uninitialized value. Such ref‐
#        erences shall not create new fields. However, assigning to  a  nonexis‐
# F;
#        create any intervening fields with the uninitialized value;  and  cause
#        the  value  of  $0 to be recomputed, with the fields being separated by
# S.  Each field variable shall have a string value or  an
#        uninitialized value when created. Field variables shall have the unini‐
# S and the variable does  not
#        contain  any  characters.  If  appropriate, the field variable shall be
# k).
#
#        Implementations shall support the  following  other  special  variables
# k:
#
# V array.
#
# V      An array of command line arguments, excluding options and the
# C−1.
#
# C  can
# k shall treat the next
# C−1,
#                  inclusive,  as the name of the next input file. Thus, setting
# V to null means that it shall not be treated
# ' indicates the standard input.
# t  operand,
# t rather than a
# e argument.
#
# f format for converting numbers to  strings  (except
# "  by
#                  default.
#
# N   An array  representing  the  value  of  the  environment,  as
# c functions defined in the System Inter‐
#                  faces volume of POSIX.1‐2008. The indices of the array  shall
#                  be  strings  consisting of the names of the environment vari‐
#                  ables, and the value of each array element shall be a  string
#                  consisting of the value of that variable. If appropriate, the
# g
# k); the array element shall also have
#                  its numeric value.
#
# k is affected  by  envi‐
#                  ronment  variables (including the environment of any commands
# m  function  or  via  pipeline
# f statement,
# e function), the environment used shall  be  the
# k began executing; it is implemen‐
# N  affects
#                  this environment.
#
# N action
# D action the value  shall
#                  be the name of the last input file processed.
#
# R       The ordinal number of the current record in the current file.
# D
#                  action  the value shall be the number of the last record pro‐
#                  cessed in the last file processed.
#
# S        Input  field  separator  regular  expression;  a  <space>  by
#                  default.
#
# N
# e  function
# D
# F shall retain the value it had for the last  record
# e function with‐
# D
#                  action.
#
# R        The  ordinal  number  of the current record from the start of
# N action the value shall be zero. Inside
# D  action  the  value  shall  be the number of the last
#                  record processed.
#
# f format for converting numbers to strings in output
# " by default. The
# T
#                  is not a floating-point format specification.
#
# t  statement  output  field  separator;  <space>  by
#                  default.
#
# t statement output record separator; a  <newline>  by
#                  default.
#
# h function.
#
# S shall be the
# S  con‐
#                  tains  more  than one character, the results are unspecified.
# S is null, then records are separated by  sequences  con‐
#                  sisting  of a <newline> plus one or more blank lines, leading
#                  or trailing blank lines shall not result in empty records  at
#                  the  beginning  or  end  of  the input, and a <newline> shall
# S
#                  is.
#
# h
#                  function, numbering from 1. This shall always  be  equivalent
# h function.
#
# P    The  subscript separator string for multi-dimensional arrays;
#                  the default value is implementation-defined.
#
# s
# k utility shall make use of the extended regular expression nota‐
# 4,
# s) except that it shall allow the use of  C-
#        language  conventions  for escaping special characters within the EREs,
#        as  specified  in  the  table  in  the  Base  Definitions   volume   of
# ',
# ') and the following table; these escape sequences
#        shall  be  recognized both inside and outside bracket expressions. Note
#        that records need not be separated by <newline> characters  and  string
# " sequence
# k EREs. Using a <slash> character within an ERE  requires
#        the escaping shown in the following table.
#
# k
#
#  ┌─────────┬────────────────────────────────────┬────────────────────────────────────┐
# e  │                                    │                                    │
# g               │
#  ├─────────┼────────────────────────────────────┼────────────────────────────────────┤
#  │\"       │ <backslash> <quotation-mark>       │ <quotation-mark> character         │
#  ├─────────┼────────────────────────────────────┼────────────────────────────────────┤
#  │\/       │ <backslash> <slash>                │ <slash> character                  │
#  ├─────────┼────────────────────────────────────┼────────────────────────────────────┤
#  │\ddd     │ A <backslash> character followed   │ The character whose encoding is    │
#  │         │ by the longest sequence of one,    │ represented by the one, two, or    │
#  │         │ two, or three octal-digit charac‐  │ three-digit octal integer. Multi-  │
#  │         │ ters (01234567). If all of the     │ byte characters require multiple,  │
#  │         │ digits are 0 (that is, representa‐ │ concatenated escape sequences of   │
#  │         │ tion of the NUL character), the    │ this type, including the leading   │
#  │         │ behavior is undefined.             │ <backslash> for each byte.         │
#  ├─────────┼────────────────────────────────────┼────────────────────────────────────┤
#  │\c       │ A <backslash> character followed   │ Undefined                          │
#  │         │ by any character not described in  │                                    │
#  │         │ this table or in the table in the  │                                    │
#  │         │ Base Definitions volume of         │                                    │
# ‐ │                                    │
# ',    │                                    │
# ').     │                                    │
#  └─────────┴────────────────────────────────────┴────────────────────────────────────┘
#        A  regular expression can be matched against a specific field or string
# '  and
# ".   These  operators  shall interpret their right-hand operand as a
#        regular expression and their left-hand operand as a string. If the reg‐
# ' expression shall evaluate
# " expression shall evaluate to a  value  of
#        0. (The regular expression matching operation is as defined by the term
# 1,
# s, where a match occurs on any part of the
#        string unless the regular expression is limited with  the  <circumflex>
#        or  <dollar-sign>  special  characters.) If the regular expression does
# ' expression shall evaluate to a  value  of
# "  expression  shall  evaluate to a value of 1. If the
# E,
#        the  string value of the expression shall be interpreted as an extended
#        regular expression, including the escape conventions  described  above.
#        Note that these same escape conventions shall also be applied in deter‐
# G),  and
#        thus  shall  be  applied a second time when a string literal is used in
#        this context.
#
# E token appears as an expression in any context other than as
# " operator or as one of the built-in
#        function arguments described below, the value of the resulting  expres‐
#        sion shall be the equivalent of:
#
# e/
#
# s argument
# s) shall  be  interpreted  as
# E tokens or arbi‐
#        trary expressions, and shall be interpreted in the same manner  as  the
# " operator.
#
#        An  extended  regular  expression  can  be  used  to separate fields by
#        assigning a string containing the expression to the  built-in  variable
# g
# S  variable  shall  be  a  single
# S behavior:
#
# S is a null string, the behavior is unspecified.
#
# S is a single character:
#
# S  is <space>, skip leading and trailing <blank> and <new‐
#                line> characters; fields shall be delimited by sets of  one  or
#                more <blank> or <newline> characters.
#
# c, fields shall be
# c.
#
# S shall  be  considered  to  be  an
#            extended regular expression. Each occurrence of a sequence matching
#            the extended regular expression shall delimit fields.
#
# t,
# b  built-in  functions,  ERE  matching  shall  be based on input
#        records; that is, record separator characters (the first  character  of
# S, <newline> by default) cannot be embedded
#        in the expression, and no expression shall match the  record  separator
#        character.  If the record separator is not <newline>, <newline> charac‐
# "
#        operators,  and in those four built-in functions, ERE matching shall be
#        based on text strings; that is, any character (including <newline>  and
#        the  record separator) can be embedded in the pattern, and an appropri‐
# k  ERE  match‐
#        ing,  the  use  of  one  or  more  NUL characters in the pattern, input
#        record, or text string produces undefined results.
#
# s
# n, a range specified by two expressions
# D.
#
# s
# D.
# N pattern shall be matched once and its associated action exe‐
#        cuted  before  the first record of input is read—except possibly by use
# s)  in  a
# D
#        pattern shall be matched once and its associated action executed  after
#        the  last  record of input has been read. These two patterns shall have
#        associated actions.
#
# N and
# N
#        patterns shall be executed in the order specified in  the  program,  as
# N pattern in a
#        program.
#
# N,  and
# k shall exit without
# N  action  is
# k program consists of only actions with the pattern
# D, the input shall be
# D actions are executed.
#
# s
#        An expression pattern shall be evaluated as if it were an expression in
#        a Boolean context. If the result is true, the pattern shall be  consid‐
#        ered to match, and the associated action (if any) shall be executed. If
#        the result is false, the action shall not be executed.
#
# s
#        A pattern range consists of two expressions separated by  a  comma;  in
#        this  case,  the  action  shall  be performed for all records between a
#        match of the first expression and the following  match  of  the  second
#        expression, inclusive. At this point, the pattern range can be repeated
#        starting at input records subsequent to the end of the matched range.
#
# s
# ‐
# r.  Any single statement can be replaced by a statement list enclosed
#        in curly braces. The application shall  ensure  that  statements  in  a
#        statement  list  are  separated by <newline> or <semicolon> characters.
#        Statements in a statement list shall be executed  sequentially  in  the
#        order that they appear.
#
# f statement shall be
#        evaluated and if it is non-zero or non-null,  the  following  statement
# e is present, the statement follow‐
# e shall be executed.
#
# e  statements  are
# m
# d), except  that  the  Boolean  expressions  shall  be
# k, and except in the case of:
#
# y)
#
# e in an
# y  within
# e statement occurs
#        outside of a loop, the behavior is undefined.
#
# e statement shall remove an individual  array  element.  Thus,
#        the following code deletes an entire array:
#
# )
# ]
#
# t  statement  shall cause all further processing of the current
# t
# D action.
#
# D actions in the order in which
#        they occur in the program source and then terminate the program without
# D action shall
# D actions.  If  an
# t statement, its numeric value shall
# k, unless subsequent errors are encountered  or
# t statement with an expression is executed.
#
# s
# f  statements  shall write to standard output by
# ‐
# n if one is supplied, as follows:
#
# n
# n
# n
#
# n shall be evaluated to produce a string
# ") or  as
# ').  Using the first two forms, if the
#        file of that name is not currently open, it shall be  opened,  creating
#        it if necessary and using the first form, truncating the file. The out‐
#        put then shall be appended to the file. As long  as  the  file  remains
# n evaluates to the same string
#        value shall simply append output to the file.  The  file  remains  open
# s) is
#        called with an expression that evaluates to the same string value.
#
#        The third form shall write output onto a stream piped to the input of a
#        command.  The  stream  shall  be created if no stream is currently open
# n as its command name.  The  stream  created
# n() function
#        defined in the System Interfaces volume of POSIX.1‐2008 with the  value
# e
#        argument. As long as the stream remains open, subsequent calls in which
# n evaluates to the same string value shall write output to the
# e  function
# s) is called with an expression
#        that evaluates to the same string value.   At  that  time,  the  stream
# e() function defined in the
#        System Interfaces volume of POSIX.1‐2008.
#
# r, these  output  state‐
# ns referred to in
# t,  or
# n
# t.
#
# t statement shall write the value of each  expression  argument
#        onto  the indicated output stream separated by the current output field
# S above), and terminated by the output record
# S above). All expression arguments shall be
#        taken as strings, being converted if necessary; this  conversion  shall
# k, with the exception that the
# T.
#        An empty expression list shall stand for the whole input record ($0).
#
# f  statement shall produce output based on a notation similar
#        to the File Format Notation used to describe file formats in this  vol‐
#        ume  of  POSIX.1‐2008 (see the Base Definitions volume of POSIX.1‐2008,
# n).  Output shall be produced  as  speci‐
# t and subse‐
# n, inclusive, with
#        the following exceptions:
#
# t shall be an actual character string rather than a graph‐
#            ical representation. Therefore, it cannot contain  empty  character
# t string, in any context other
# g of a conversion specification, shall be treated  as  an
#            ordinary character that is copied to the output.
#
# '' character and that character
# t string, it shall be treated  as  an  ordinary
#            character that is copied to the output.
#
# s beginning with a <backslash> character shall
#            be treated as sequences of ordinary characters that are  copied  to
#            the  output.  Note  that  these same sequences shall be interpreted
# k when they appear  in  literal  strings,  but  they
# f statement.
#
# ' character
#            instead of a digit string. In this case the next argument from  the
#            expression list shall be fetched and its numeric value taken as the
#            field width or precision.
#
# d or
# u conversion specifier characters with <blank> characters not spec‐
# t string.
#
# o  conversion
# t
#            string.
#
# c conversion specifier character: if  the  argument  has  a
#            numeric  value, the character whose encoding is that value shall be
#            output. If the value is zero or is not the encoding of any  charac‐
#            ter  in  the character set, the behavior is undefined. If the argu‐
#            ment does not have a numeric value,  the  first  character  of  the
#            string  value  shall  be output; if the string does not contain any
#            characters, the behavior is undefined.
#
#         8. For each conversion specification that consumes  an  argument,  the
#            next  expression argument shall be evaluated. With the exception of
# c conversion specifier character, the value shall be  converted
# k) to the
#            appropriate type for the conversion specification.
#
#         9. If there are insufficient expression arguments to satisfy  all  the
# t string, the behavior is
#            undefined.
#
# '
#            character,  but does not form a valid conversion specification, the
#            behavior is unspecified.
#
# f can output at least {LINE_MAX} bytes.
#
# s
# k language has  a  variety  of  built-in  functions:  arithmetic,
#        string, input/output, and general.
#
# s
# t, shall be based on the ISO C
# d).
#        The  behavior  is undefined in cases where the ISO C standard specifies
#        that an error be returned or that the behavior is  undefined.  Although
# r) permits built-in functions to appear with no
#        arguments or parentheses, unless the argument or parentheses are  indi‐
#        cated  as optional in the following list (by displaying them within the
# " brackets), such use is undefined.
#
# x)
# x in radians in the range [−π,π].
#
# x is in radians.
#
# x is in radians.
#
# x.
#
# x.
#
# x.
#
# x)    Return the argument truncated to an integer. Truncation shall
# x>0.
#
# n<1.
#
# ])
# r or use the time of day if
# r is omitted. The previous seed value shall be returned.
#
# s
#        The  string  functions  in  the  following  list  shall  be  supported.
# r) permits built-in functions to appear
#        with no arguments or parentheses, unless the  argument  or  parentheses
#        are  indicated  as  optional  in the following list (by displaying them
# " brackets), such use is undefined.
#
# ])
# b (see below), except that it shall replace all
# d utility
# n argument,  when  speci‐
#                  fied.
#
# t)
#                  Return  the  position,  in  characters,  numbering from 1, in
# t first occurs, or zero if it does  not
#                  occur at all.
#
# ]
#                  Return  the length, in characters, of its argument taken as a
#                  string, or of the whole record, $0, if there is no argument.
#
# e)
#                  Return the position, in  characters,  numbering  from  1,  in
# e occurs, or
#                  zero if it does not occur at all. RSTART shall be set to  the
#                  starting  position (which is the same as the returned value),
#                  zero if no match is found; RLENGTH shall be set to the length
#                  of the matched string, −1 if no match is found.
#
# ])
# n],
# n.  All elements of the  array  shall  be  deleted
#                  before  the  split is performed. The separation shall be done
# s  is  not
#                  given. Each array element shall have a string value when cre‐
#                  ated and, if appropriate, the array element shall be  consid‐
# k).  The effect
# s is unspecified.
#
# r, ...)
# f  format  given
# t and return the resulting string.
#
# ])
# l in place of the first instance of
# n  and  return
# ') appearing
# n
#                  that  matches  the ERE. An <ampersand> preceded with a <back‐
#                  slash> shall be interpreted as the literal <ampersand>  char‐
#                  acter.  An  occurrence of two consecutive <backslash> charac‐
#                  ters shall be interpreted as just  a  single  literal  <back‐
#                  slash>  character. Any other occurrence of a <backslash> (for
#                  example, preceding any other character) shall be treated as a
# l is a string
# r), the handling
#                  of  the  <ampersand>  character occurs after any lexical pro‐
#                  cessing, including any  lexical  <backslash>-escape  sequence
# n is specified and it is not an lvalue (see
# n  is
# k shall use the current record ($0) in its place.
#
# ])
# s that begins at
# n speci‐
#                  fies  more characters than are left in the string, the length
#                  of the substring shall be limited by the length of the string
# s.
#
# s)
# s
# r  map‐
# E category of the current locale shall be
#                  replaced in the returned string by the lowercase letter spec‐
# s  shall  be
#                  unchanged in the returned string.
#
# s)
# s
# r map‐
# E  category  of  the  current  locale  is
#                  replaced in the returned string by the uppercase letter spec‐
# s are unchanged  in
#                  the returned string.
#
# E as a parameter expect a
#        pattern or a string valued expression that is a regular  expression  as
# s.
#
# s
#        The input/output and general functions are:
#
# n)
# f statement
# n.
# n arguments is
#                  implementation-defined. If  the  close  was  successful,  the
#                  function  shall  return zero; otherwise, it shall return non-
#                  zero.
#
# ]
#                  Read a record of input from a stream piped from the output of
#                  a  command.  The stream shall be created if no stream is cur‐
# n as its command name.
#                  The  stream  created  shall be equivalent to one created by a
# n  as
# e argument.
#                  As long as the stream remains open, subsequent calls in which
# n evaluates to the same string value shall read sub‐
#                  sequent records from the stream. The stream shall remain open
# e  function is called with an expression that
#                  evaluates to the same string value. At that time, the  stream
# e() function. If
# r  shall
#                  be  set and, if appropriate, it shall be considered a numeric
# k).
#
# e operator can form ambiguous constructs when there
#                  are  unparenthesized operators (including concatenate) to the
# ' (to the beginning of the expression  contain‐
# ' shall
# '.  The  result
#                  of  evaluating other operators is unspecified, and conforming
#                  applications shall parenthesize properly all such usages.
#
# e   Set $0 to the next input record from the current input  file.
# R variables.
#
# r
# r  to the next input record from the current
# r  shall  be  considered  a
# ‐
# R variables.
#
# n
# ‐
# n shall be evaluated to produce a string that is used as a
#                  pathname.  If the file of that name is not currently open, it
#                  shall  be  opened. As long as the stream remains open, subse‐
# n evaluates to the same  string
#                  value  shall  read subsequent records from the file. The file
# e function is called with  an
# r is
# r shall be  set
#                  and,  if appropriate, it shall be considered a numeric string
# k).
#
# e operator can form ambiguous constructs when there
#                  are  unparenthesized binary operators (including concatenate)
# ' (up to the end of the expression con‐
# e).  The result of evaluating such a con‐
#                  struct is  unspecified,  and  conforming  applications  shall
#                  parenthesize properly all such usages.
#
# n)
# n in a manner equiva‐
# m() function defined in  the  System  Inter‐
#                  faces  volume  of  POSIX.1‐2008 and return the exit status of
#                  the command.
#
# e shall return 1 for successful input, zero for end-
#        of-file, and −1 for an error.
#
#        Where  strings are used as the name of a file or pipeline, the applica‐
#        tion shall ensure that the strings are textually identical. The  termi‐
#        nology  ``same string value'' implies that ``equivalent strings'', even
#        those that differ  only  by  <space>  characters,  represent  different
#        files.
#
# s
# k  language also provides user-defined functions. Such functions
#        can be defined as:
#
# s }
#
# k program;  in  particu‐
#        lar,  its  use  can  precede its definition. The scope of a function is
#        global.
#
#        Function parameters, if present, can be either scalars or  arrays;  the
#        behavior  is  undefined  if an array name is passed as a parameter that
#        the function uses as a scalar, or if a scalar expression is passed as a
#        parameter that the function uses as an array. Function parameters shall
#        be passed by value if scalar and by reference if array name.
#
#        The number of parameters in the function definition need not match  the
#        number of parameters in the function call. Excess formal parameters can
#        be used as local variables. If fewer arguments are supplied in a  func‐
#        tion  call  than  are  in the function definition, the extra parameters
#        that are used in the function body as scalars  shall  evaluate  to  the
#        uninitialized value until they are otherwise initialized, and the extra
#        parameters that are used in  the  function  body  as  arrays  shall  be
#        treated  as  uninitialized  arrays  where each element evaluates to the
#        uninitialized value until otherwise initialized.
#
#        When invoking a function, no white space  can  be  placed  between  the
#        function name and the opening parenthesis. Function calls can be nested
#        and recursive calls can be made upon functions. Upon  return  from  any
#        nested  or  recursive  function  call, the values of all of the calling
#        function's parameters shall be unchanged, except for  array  parameters
# n  statement  can be used to return a
# n statement appears outside of a function  definition,
#        the behavior is undefined.
#
#        In  the  function  definition,  <newline>  characters shall be optional
#        before the opening brace and after the closing brace. Function  defini‐
# n pair is
#        allowed.
#
# r
#        The grammar in this section and the lexical conventions in the  follow‐
# k programs. The
# n
# s.   A valid program can be represented as the
# m in the grammar. This  formal  syntax  shall
#        take precedence over the preceding text syntax description.
#
# E
# /
#
#            /* Keywords */
#            %token       Begin   End
#            /*          'BEGIN' 'END'                            */
#
#            %token       Break   Continue   Delete   Do   Else
#            /*          'break' 'continue' 'delete' 'do' 'else'  */
#
#            %token       Exit   For   Function   If   In
#            /*          'exit' 'for' 'function' 'if' 'in'        */
#
#            %token       Next   Print   Printf   Return   While
#            /*          'next' 'print' 'printf' 'return' 'while' */
#
#            /* Reserved function names */
#            %token BUILTIN_FUNC_NAME
#                        /* One token for the following:
#                         * atan2 cos sin exp log sqrt int rand srand
#                         * gsub index length match split sprintf sub
#                         * substr tolower toupper close system
#                         */
#            %token GETLINE
#                        /* Syntactically different from other built-ins. */
#
#            /* Two-character tokens. */
#            %token ADD_ASSIGN SUB_ASSIGN MUL_ASSIGN DIV_ASSIGN MOD_ASSIGN POW_ASSIGN
#            /*     '+='       '−='       '*='       '/='       '%='       '^=' */
#
#            %token OR   AND  NO_MATCH   EQ   LE   GE   NE   INCR  DECR  APPEND
#            /*     '||' '&&' '!~' '==' '<=' '>=' '!=' '++'  '−−'  '>>'   */
#
#            /* One-character tokens. */
#            %token '{' '}' '(' ')' '[' ']' ',' ';' NEWLINE
#            %token '+' '−' '*' '%' '^' '!' '>' '<' '|' '?' ':' ' " " ' '$' '='
#
#            %start program
#            %%
#
#            program          : item_list
#                             | actionless_item_list
#                             ;
#
#            item_list        : newline_opt
#                             | actionless_item_list item terminator
#                             | item_list            item terminator
#                             | item_list          action terminator
#                             ;
#
#            actionless_item_list : item_list            pattern terminator
#                             | actionless_item_list pattern terminator
#                             ;
#
#            item             : pattern action
#                             | Function NAME      '(' param_list_opt ')'
#                                   newline_opt action
#                             | Function FUNC_NAME '(' param_list_opt ')'
# ...
# k language does provide.
#
# k have been extended somewhat from historical
#        implementations to make  them  a  pure  superset  of  extended  regular
#        expressions,  as defined by POSIX.1‐2008 (see the Base Definitions vol‐
# s).   The
#        main  extensions are internationalization features and interval expres‐
# k  have  long  supported  <back‐
#        slash>-escape  sequences  as  an  extension to extended regular expres‐
#        sions, and this extension has been retained despite inconsistency  with
#        other  utilities.  The  number  of  escape sequences recognized in both
#        extended regular expressions and strings has varied (generally increas‐
#        ing with time) among implementations. The set specified by POSIX.1‐2008
#        includes most sequences known to be supported  by  popular  implementa‐
#        tions  and by the ISO C standard. One sequence that is not supported is
# '.  This would allow values
# k as in the ISO C
#        standard. However, because this syntax has a non-deterministic  length,
#        it  does not permit the subsequent character to be a hexadecimal digit.
#        This limitation can be dealt with in the C language by the use of lexi‐
# k language, concatenation could also
#        be a solution for strings, but not  for  extended  regular  expressions
#        (either  lexical  ERE  tokens  or  strings  used dynamically as regular
#        expressions). Because of this limitation,  the  feature  has  not  been
#        added to POSIX.1‐2008.
#
#        When  a  string variable is used in a context where an extended regular
#        expression normally appears (where the lexical token ERE is used in the
#        grammar) the string does not contain the literal <slash> characters.
#
# k allow the form:
#
# }
#
#        This has been deprecated by the authors of the language, who asked that
#        it not be specified.
#
# t  statement
# t
# D action. This behavior has not been doc‐
#        umented,  and  it was not believed that it was necessary to standardize
#        it.
#
#        The specification of conversions between string and numeric  values  is
#        much  more detailed than in the documentation of historical implementa‐
# e. Although  most
#        of  the behavior is designed to be intuitive, the details are necessary
#        to ensure compatible behavior from different implementations.  This  is
#        especially  important  in relational expressions since the types of the
#        operands determine whether a string or numeric comparison is performed.
#        From  the perspective of an application developer, it is usually suffi‐
#        cient to expect intuitive behavior and to force conversions (by  adding
#        zero  or  concatenating  a  null string) when the type of an expression
#        does not obviously match what is needed. The intent has been to specify
#        historical  practice in almost all cases. The one exception is that, in
#        historical  implementations,  variables  and  constants  maintain  both
#        string  and  numeric  values after their original value is converted by
#        any use. This means that referencing a variable or  constant  can  have
#        unexpected  side-effects.  For example, with historical implementations
#        the following program:
#
# {
# "
# 2
# )
# b
# )
# "
# e
# "
# }
#
#        would perform a numeric comparison (and output numeric comparison)  for
#        each  odd-numbered  line,  but  perform a string comparison (and output
#        string comparison) for each even-numbered  line.  POSIX.1‐2008  ensures
#        that  comparisons  will be numeric if necessary. With historical imple‐
#        mentations, the following program:
#
# {
# "
# 4
# "
# 4
# }
#
# t  state‐
# " would have a string value from the previous
# t
# ".   The behavior of historical implementations
#        was seen as too unintuitive and unpredictable.
#
#        It was pointed out that with the rules contained in early  drafts,  the
#        following script would print nothing:
#
# {
# 1
# "
# ]
# }
#
# T variable
#        is now restricted to affecting output conversions of numbers to strings
# T  is  used for internal conversions, such as comparisons or
# T,  so
# T (which no historical program would
#        do), it will receive the historical behavior associated  with  internal
#        string conversions.
#
# k lexical and syntactic conventions are specified more for‐
#        mally than in other sources. Again the intent has been to specify  his‐
#        torical  practice. One convention that may not be obvious from the for‐
#        mal grammar as in other verbal descriptions is where <newline>  charac‐
#        ters  are acceptable. There are several obvious placements such as ter‐
#        minating a statement, and a <backslash> can be used to escape <newline>
#        characters  between  any lexical tokens. In addition, <newline> charac‐
#        ters without <backslash> characters can follow a comma, an open  brace,
# o
# r,
# e statement. For example:
#
# ,
# }
#
# k add a trailing <newline> to the program argu‐
#        ment text is to simplify the grammar, making it match a  text  file  in
#        form.  There  is  no  way for an application or test suite to determine
# k simply acts  as  if
#        it did.
#
#        POSIX.1‐2008  requires  several changes from historical implementations
#        in order to support internationalization. Probably the most  subtle  of
#        these  is  the  use  of  the  decimal-point  character,  defined by the
# C category of the locale, in representations of floating-point
#        numbers.  This locale-specific character is used in recognizing numeric
#        input, in converting between strings and numeric values, and in format‐
#        ting output. However, regardless of locale, the <period> character (the
#        decimal-point character of the POSIX locale) is the decimal-point char‐
# k programs (including assignments in
#        command line arguments). This is essentially the same convention as the
#        one  used  in the ISO C standard. The difference is that the C language
# e() function, which permits an application to mod‐
#        ify its locale. Because of this capability, a C application begins exe‐
#        cuting with its locale set to the C locale, and only  executes  in  the
# e().
# k  language  was
#        seen  as  inappropriate  for POSIX.1‐2008. It is possible to execute an
# k program explicitly in any desired locale by setting the environment
#        in the shell.
#
#        The  undefined behavior resulting from NULs in extended regular expres‐
# k  program  to  process
#        binary data.
#
# k programs (including lexical,
#        syntactic, and semantic errors) is undefined because it was  considered
#        overly  limiting  on  implementations  to  specify.  In most cases such
#        errors can be expected to produce a diagnostic and a non-zero exit sta‐
#        tus. However, some implementations may choose to extend the language in
#        ways that make use of certain invalid constructs.  Other  invalid  con‐
#        structs  might  be deemed worthy of a warning, but otherwise cause some
#        reasonable behavior. Still other constructs may be  very  difficult  to
#        detect  in some implementations.  Also, different implementations might
#        detect a given error during an initial parsing of the  program  (before
#        reading  any  input  files) while others might detect it when executing
#        the program after reading some input. Implementors should be aware that
#        diagnosing errors as early as possible and producing useful diagnostics
#        can ease debugging of applications, and  thus  make  an  implementation
#        more usable.
#
# S values is to
#        allow possible future extensions based on extended regular  expressions
#        used  for  record separators. Historical implementations take the first
#        character of the string and ignore the others.
#
# y,<null>)  is  used  is  to
#        allow  a proposed future extension that would split up a string into an
#        array of individual characters.
#
# e function, equally good arguments for dif‐
# < operators can be made. Historical
#        practice has been that:
#
# "
#
#        is parsed as:
#
# "
#
# b  should
#        be read. However:
#
# 1
#
#        parses as:
#
# )
#
# e, particularly in
# $.  For example:
#
# e
#
# t state‐
# t.)
#
#        Since in most cases such constructs are not (or at least should not) be
#        used (because they have a natural ambiguity for which there is no  con‐
#        ventional  parsing),  the  meaning  of  these  constructs has been made
#        explicitly unspecified. (The effect is that  a  conforming  application
#        that runs into the problem must parenthesize to resolve the ambiguity.)
#        There appeared to be few if any actual uses of such constructs.
#
#        Grammars can be written that would cause an error under  these  circum‐
#        stances.  Where  backwards-compatibility  is not a large consideration,
#        implementors may wish to use such grammars.
#
#        Some historical implementations have allowed some built-in functions to
#        be called without an argument list, the result being a default argument
# h as a synonym  for
# )  is the only one of these forms that is thought to be widely
#        known or widely used; this particular form  is  documented  in  various
# k reference pages, although not
# e) as legitimate practice.
#        With  this  exception,  default argument lists have always been undocu‐
#        mented and vaguely defined, and it is not at all clear how (or if) they
#        should  be  generalized  to  user-defined functions. They add no useful
#        functionality and preclude possible future extensions that  might  need
#        to  name  functions  without calling them. Not standardizing them seems
# h
#        merited special treatment, however, since it has been documented in the
#        past and sees possibly substantial use in historical programs.  Accord‐
#        ingly,  this  usage  has  been made legitimate, but Issue 5 removed the
#        obsolescent marking for XSI-conforming implementations and many  other‐
#        wise conforming applications depend on this feature.
#
# l  is  a  string literal (the lexical token
# G), then two consecutive <backslash> characters should be used  in
#        the  string to ensure a single <backslash> will precede the <ampersand>
#        when the resultant string is passed to the function. (For  example,  to
#        specify   one  literal  <ampersand>  in  the  replacement  string,  use
# ").)
#
# b
# ') character and pre‐
#        ceding it with the <backslash> character was used to turn off its  spe‐
#        cial meaning.
#
#        The  description  in  the ISO POSIX‐2:1993 standard introduced behavior
#        such that the <backslash> character was another special  character  and
#        it  was  unspecified  whether  there were any other special characters.
#        This description introduced several portability problems, some of which
#        are described below, and so it has been replaced with the more histori‐
#        cal description. Some of the problems include:
#
#         *  Historically, to create the replacement string, a script could  use
# "),  but with the ISO POSIX‐2:1993 standard wording,
# ").  The <backslash>  char‐
#            acters  are doubled here because all string literals are subject to
#            lexical analysis, which would reduce each pair of <backslash> char‐
# b.
#
#         *  Since it was unspecified what the special characters were, for por‐
#            table scripts to guarantee that characters are  printed  literally,
#            each  character  had to be preceded with a <backslash>.  (For exam‐
# ") to produce  a
# ".)
#
#        The  description  for  comparisons in the ISO POSIX‐2:1993 standard did
#        not properly describe historical practice because of  the  way  numeric
#        strings  are compared as numbers. The current rules cause the following
#        code:
#
# )
# "
# e
# "
#
# f to  succeed.  It  should  be
#        intuitively  obvious  that  this  is incorrect behavior, and indeed, no
# k actually behaves this way.
#
# g was  enhanced  to
#        include  only those values obtained from specific circumstances (mostly
#        external sources) where it is not possible to  determine  unambiguously
#        whether the value is intended to be a string or a numeric.
#
#        Variables  that  are assigned to a numeric string shall also be treated
#        as a numeric string. (For example, the notion of a numeric  string  can
#        be propagated across assignments.) In comparisons, all variables having
#        the uninitialized value are to be treated as a numeric operand evaluat‐
#        ing to the numeric value zero.
#
#        Uninitialized  variables  include  all  types  of  variables  including
#        scalars, array elements, and fields. The definition of an uninitialized
# s is necessary to describe the
#        value placed on uninitialized variables and on fields  that  are  valid
# F) but have no characters in them and to describe how
#        these variables are to be used in comparisons. A valid field,  such  as
# 1,  that has no characters in it can be obtained from an input line of
# <10)  was  done
# 1 to the value zero.
#
#        The  phrase  ``...  also  shall  have  the numeric value of the numeric
#        string'' was removed from  several  sections  of  the  ISO POSIX‐2:1993
#        standard  because is specifies an unnecessary implementation detail. It
#        is not necessary for POSIX.1‐2008 to  specify  that  these  objects  be
#        assigned  two  different  values.  It is only necessary to specify that
#        these objects may evaluate to two different values  depending  on  con‐
#        text.
#
# k did not parse hexadecimal integer or
# ".  Due to  an  oversight,  the
#        2001  through 2004 editions of this standard required support for hexa‐
# f().
#        This  version  of  the standard allows but does not require implementa‐
# f() and includes a description  of  how  floating-point
#        numbers  are  recognized  as an alternative to match historic behavior.
#        The intent of this change is  to  allow  implementations  to  recognize
#        floating-point  constants  according  to  either  the ISO/IEC 9899:1990
#        standard or ISO/IEC 9899:1999 standard, and to allow (but not  require)
#        implementations to recognize hexadecimal integer constants.
#
# k  did  not  support  floating-point
# ".   How‐
# d() functions to do
#        the conversion picked up support  for  these  values  if  they  used  a
#        ISO/IEC 9899:1999  standard  version  of  the  function  instead  of  a
#        ISO/IEC 9899:1990 standard version.  Due  to  an  oversight,  the  2001
#        through  2004  editions  of  this  standard  did  not allow support for
#        infinities and NaNs, but in this revision support is allowed  (but  not
# k programs; for
#        example, in the POSIX locale the expression:
#
# )
#
# " converted to 0, but now it  may
#        have the value 0 or 1.
#
# S
#        None.
#
# O
# d
#
# t
# t
# x
# s
#
# e(),
# d()
#
# T
#        Portions  of  this text are reprinted and reproduced in electronic form
#        from IEEE Std 1003.1, 2013 Edition, Standard for Information Technology
#        --  Portable  Operating  System  Interface (POSIX), The Open Group Base
#        Specifications Issue 7, Copyright (C) 2013 by the Institute of Electri‐
#        cal  and  Electronics  Engineers,  Inc  and  The  Open Group.  (This is
#        POSIX.1-2008 with the 2013 Technical Corrigendum  1  applied.)  In  the
#        event of any discrepancy between this version and the original IEEE and
#        The Open Group Standard, the original IEEE and The Open Group  Standard
#        is  the  referee document. The original Standard can be obtained online
#        at http://www.unix.org/online.html .
#
#        Any typographical or formatting errors that appear  in  this  page  are
#        most likely to have been introduced during the conversion of the source
#        files to man page format. To report such errors,  see  https://www.ker‐
#        nel.org/doc/man-pages/reporting_bugs.html .
#
# IEEE/The Open Group                  2013                          AWK(1POSIX)
