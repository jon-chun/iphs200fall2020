# %% [markdown]
# # **Twitter Step 1: Search and Combine Tweets in one Datafile.csv**
# By: Jon Chun
# 30 Nov 2020
#
# Reference:
#
# * https://www.youtube.com/watch?v=_SqgSh3aR1g (20201127 10:17)
# * https://null-byte.wonderhowto.com/how-to/mine-twitter-for-targeted-information-with-twint-0193853/ (20190502)
# * https://github.com/twintproject/twint/wiki (wiki)
# * https://pielco11.ovh/posts/twint-osint/ (osint)

# %% [markdown]
# # **0. Setup Environment**

# %% [markdown]
# ## You will need to give permission for this Colab to link to your gdrive in the code cell below

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# CUSTOMIZE: if you want your work and twitter datasets saved into a specific folder
#            beneath your gdrive root directory, define it below

# %cd ./MyDrive/courses/2020f_iphs200_programming_humanity/code/
# Out:
# /gdrive/MyDrive/courses/2020f_iphs200_programming_humanity/code

# %%
# !git clone --depth=1 https://github.com/twintproject/twint.git
# Out:
# fatal: destination path 'twint' already exists and is not an empty directory.

# %%
# %cd twint
# Out:
# /gdrive/My Drive/courses/2020f_iphs200_programming_humanity/code/twint

# %%
# RESTART RUNTIME button at end of output

# !pip3 install . -r requirements.txt
# Out:
# Processing /content/twint
# Collecting aiohttp
#   Downloading https://files.pythonhosted.org/packages/ad/e6/d4b6235d776c9b33f853e603efede5aac5a34f71ca9d3877adb30492eb4e/aiohttp-3.7.3-cp36-cp36m-manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 8.7MB/s
# Collecting aiodns
#   Downloading https://files.pythonhosted.org/packages/da/01/8f2d49b441573fd2478833bdba91cf0b853b4c750a1fbb9e98de1b94bb22/aiodns-2.0.0-py2.py3-none-any.whl
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (4.6.3)
# Collecting cchardet
#   Downloading https://files.pythonhosted.org/packages/a0/e5/a0b9edd8664ea3b0d3270c451ebbf86655ed9fc4c3e4c45b9afae9c2e382/cchardet-2.1.7-cp36-cp36m-manylinux2010_x86_64.whl (263kB)
#      |████████████████████████████████| 266kB 20.2MB/s
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (0.8)
# Collecting elasticsearch
#   Downloading https://files.pythonhosted.org/packages/14/ba/f950bdd9164fb2bbbe5093700162234fbe61f446fe2300a8993761c132ca/elasticsearch-7.10.0-py2.py3-none-any.whl (321kB)
#      |████████████████████████████████| 327kB 34.8MB/s
# Requirement already satisfied: pysocks in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (1.7.1)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 8)) (1.1.4)
# Collecting aiohttp_socks<=0.4.1
#   Downloading https://files.pythonhosted.org/packages/72/55/c00bf359a54c1438ac0fe36f9bba9538c912138f033897d4e95ddd8cc772/aiohttp_socks-0.4.1-py3-none-any.whl
# Collecting schedule
#   Downloading https://files.pythonhosted.org/packages/57/22/3a709462eb02412bd1145f6e53604f36bba191e3e4e397bea4a718fec38c/schedule-0.6.0-py2.py3-none-any.whl
# Requirement already satisfied: geopy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 11)) (1.17.0)
# Collecting fake-useragent
#   Downloading https://files.pythonhosted.org/packages/d1/79/af647635d6968e2deb57a208d309f6069d31cb138066d7e821e575112a80/fake-useragent-0.1.11.tar.gz
# Collecting googletransx
#   Downloading https://files.pythonhosted.org/packages/27/e1/77cd530afec7944d40c5bdd260bcc111be4012b045c82d4e3ffec90b2a42/googletransx-2.4.2.tar.gz
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Collecting idna-ssl>=1.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/46/03/07c4894aae38b0de52b52586b24bf189bb83e4ddabfe2e2c8f2419eec6f4/idna-ssl-1.1.0.tar.gz
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/da/08/52b26b44bce7b818b410aee37c5e424c9ea420c557bca97dc2adac29b151/yarl-1.6.3-cp36-cp36m-manylinux2014_x86_64.whl (293kB)
#      |████████████████████████████████| 296kB 23.2MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->-r requirements.txt (line 1)) (20.3.0)
# Collecting multidict<7.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/a5/95/f89c97db4d27b24fce7c6fb6ef05228f347e43bbf67e4737a0660c8753fd/multidict-5.0.2-cp36-cp36m-manylinux2014_x86_64.whl (141kB)
#      |████████████████████████████████| 143kB 27.7MB/s
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp->-r requirements.txt (line 1)) (3.7.4.3)
# Collecting pycares>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/43/2d/7f4984a23f6e99cf6a8b20ddc59308efb209fe81e79c97af65e9b30eefae/pycares-3.1.1-cp36-cp36m-manylinux2010_x86_64.whl (228kB)
#      |████████████████████████████████| 235kB 16.9MB/s
# Collecting typing; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/05/d9/6eebe19d46bd05360c9a9aae822e67a80f9242aabbfc58b641b957546607/typing-3.7.4.3.tar.gz (78kB)
#      |████████████████████████████████| 81kB 5.5MB/s
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from elasticsearch->-r requirements.txt (line 6)) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from elasticsearch->-r requirements.txt (line 6)) (2020.11.8)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->-r requirements.txt (line 8)) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->-r requirements.txt (line 8)) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->-r requirements.txt (line 8)) (1.18.5)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.6/dist-packages (from geopy->-r requirements.txt (line 11)) (1.50)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from googletransx->-r requirements.txt (line 13)) (2.23.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.6/dist-packages (from idna-ssl>=1.0; python_version < "3.7"->aiohttp->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: cffi>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pycares>=3.0.0->aiodns->-r requirements.txt (line 2)) (1.14.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->-r requirements.txt (line 8)) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.5.0->pycares>=3.0.0->aiodns->-r requirements.txt (line 2)) (2.20)
# Building wheels for collected packages: fake-useragent, googletransx, twint, idna-ssl, typing
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp36-none-any.whl size=13485 sha256=0a5dc4016c3490797d6ed95a9ea8174aaa379d25f6ece695746b01e9c5d9226f
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
#   Building wheel for googletransx (setup.py) ... done
#   Created wheel for googletransx: filename=googletransx-2.4.2-cp36-none-any.whl size=15971 sha256=b67ba111603c00d86f3945f87ce3085b8cff28ff11df5c96f159733f3368321c
#   Stored in directory: /root/.cache/pip/wheels/04/63/5f/75e7e94eb62517946116a783e4cd8970c4789c990bbc732616
#   Building wheel for twint (setup.py) ... done
#   Created wheel for twint: filename=twint-2.1.21-cp36-none-any.whl size=38674 sha256=335c3e6b9c3bc841845ec6edc71f67c3c4c629c1d8794751567452d6769be3f5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jwa2_4qo/wheels/c9/bb/bd/2b559954ecc4f4905266df71e9f2e08268750df0fa1ec1a4d2
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3161 sha256=fa3876f8501081ad669fd4b26ad6af82e57c7c7fae15c9354f331aff3651922c
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-cp36-none-any.whl size=26307 sha256=e04f0ea566d1ee6e8090984395b02f71d5d25fba552cbb103216202b69215400
#   Stored in directory: /root/.cache/pip/wheels/2d/04/41/8e1836e79581989c22eebac3f4e70aaac9af07b0908da173be
# Successfully built fake-useragent googletransx twint idna-ssl typing
# Installing collected packages: async-timeout, idna-ssl, multidict, yarl, aiohttp, pycares, typing, aiodns, cchardet, elasticsearch, aiohttp-socks, schedule, fake-useragent, googletransx, twint
# Successfully installed aiodns-2.0.0 aiohttp-3.7.3 aiohttp-socks-0.4.1 async-timeout-3.0.1 cchardet-2.1.7 elasticsearch-7.10.0 fake-useragent-0.1.11 googletransx-2.4.2 idna-ssl-1.1.0 multidict-5.0.2 pycares-3.1.1 schedule-0.6.0 twint-2.1.21 typing-3.7.4.3 yarl-1.6.3

# %% [markdown]
# ## You should [RESTART RUNTIME] at this point before continuing

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
import glob

import time

# %%
import twint

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# # **1. DEFINE and RUN Searches**

# %%
search_terms_ls = []

# %% [markdown]
# ## (a). Define your search_terms and/or user_name in the following code cell

# %%
# STEP ONE: DEFINE search

# Define your search terms and/or user (you must set values for at least one of these, both ok too)

# CUSTOMIZE: If you want to limit your search to a particular user set 'username' to it
user_name = 'joebiden'

# CUSTOMIZE: If you want to search for key terms in the tweet, set 'search_terms'
search_terms = 'vote court'

# %%
# STEP TWO: RUN search

# Create a filename of search results in a file with the name contained a unique timestamp
timestr = time.strftime("%Y%m%d-%H%M%S")
search_str = '_'.join(search_terms.split())
file_name = f"tweets_twint_{search_str}__{timestr}.csv"

# Save your user/search terms
search_terms_both = f"USERNAME:{user_name} and SEARCHTERMS:{search_terms}"
search_terms_ls.append(search_terms_both)

# Run your search
c = twint.Config()
if len(user_name) > 0:
  c.Username = user_name
if len(search_terms) > 0:
  c.Search = search_terms

if (len(user_name) != 0)  | (len(search_terms) != 0):
  c.Limit = 1000    # Limit of how many tweets to retrieve
  c.Store_object=True
  c.Store_csv = True
  c.Output = file_name # "tweets.csv"
  twint.run.Search(c)
else:
  print("You need to set user_name and/or search_terms to a non-null value")
# Out:
# 1324531952230289408 2020-11-06 02:00:00 +0000 <JoeBiden> Donald Trump is going to court to stop votes from being counted. We have assembled the largest election protection effort in history to fight back and need your help.  Chip in to make sure every vote is counted:  https://t.co/ksrwxu9nDE
# 1323373064277680128 2020-11-02 21:15:00 +0000 <JoeBiden> Health care.  Civil rights. Climate change.  Economic inequality.  Racial justice. The Supreme Court. Our democracy.  They’re all at stake. Vote.  https://t.co/eoxT07d7QB
# 1320933992443465728 2020-10-27 03:43:00 +0000 <JoeBiden> The rushed and unprecedented confirmation of Amy Coney Barrett as Associate Justice to the Supreme Court, in the middle of an ongoing election, should be a stark reminder to every American that your vote matters.  https://t.co/NwEi4jyMd1
# 1316402131197452288 2020-10-14 15:35:00 +0000 <JoeBiden> If President Trump is successful in forcing through his nominee to the U.S. Supreme Court, it will likely repeal the ACA and 100 million Americans with pre-existing conditions will lose their protections.   Vote like your health care depends on it. Because it does.  https://t.co/XgY2aGRZq2
# 1312907856161705985 2020-10-05 00:10:00 +0000 <JoeBiden> The economy. Climate change. Health care. Civil rights. Racial justice. The U.S. Supreme Court. Our democracy.  They’re all on the line. Vote.  https://t.co/eoxT07d7QB
# 1309966978006753280 2020-09-26 21:24:00 +0000 <JoeBiden> Today, President Trump nominated Judge Amy Coney Barrett to the Supreme Court — a jurist with a written track record of disagreeing with the Court’s decision to uphold the Affordable Care Act.  Vote like your health care is on the ballot — because it is.  https://t.co/TDBQOVLP4K
# 1307445614184198151 2020-09-19 22:25:00 +0000 <JoeBiden> The Supreme Court is on the ballot. And the outcome will impact everything from health care to civil rights — affecting generations to come.   Vote. Our future depends on it.  https://t.co/Hy8C4mIL2M
# 1203088557075828736 2019-12-06 23:07:18 +0000 <JoeBiden> The Voting Rights Act used to be one of our best tools to fight state laws designed to suppress the vote — particularly the votes of people of color. Then it was gutted by the Supreme Court, and Congressional Republicans have refused a legislative fix.
# 1158881605005565955 2019-08-06 23:24:40 +0000 <JoeBiden> But our job is not done. The #VotingRightsAct has been gutted by the Supreme Court &amp; voting rights are under siege across the country.  As president, I will restore the VRA, stand up to attacks on the right to vote, &amp; renew our efforts to ensure every American’s voice is equal.
# 1058734197655912448 2018-11-03 14:54:37 +0000 <JoeBiden> Voting restrictions in Georgia weren’t meant to protect the sanctity of our vote, but to suppress turnout. I applaud the court rulings to overturn them and right these wrongs.   We should be making voting easier, not harder. Now let’s prove nothing can stop us. Vote.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %% [markdown]
# ## (b). Go back and run the last two code cells DEFINE SEARCH and RUN SEARCH until:
#
# * You modify your searches to focus in on what you want to find out
# * You have gathered enough tweets necessary for rigourous analysis

# %%
# !pwd
# Out:
# /gdrive/My Drive/courses/2020f_iphs200_programming_humanity/code

# %%
# !ls -al tweets_twint*
# Out:
# -rw------- 1 root root 397295 Dec  1 01:22 tweets_twint_donald_trump__20201201-012233.csv
# -rw------- 1 root root   7826 Dec  1 01:22 tweets_twint_election_win__20201201-012219.csv
# -rw------- 1 root root 106021 Dec  1 01:21 tweets_twint_future__20201201-012121.csv
# -rw------- 1 root root   5478 Dec  1 01:23 tweets_twint_vote_court__20201201-012309.csv

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               6 non-null      Int64
#  1   conversation_id  6 non-null      Int64
#  2   created_at       6 non-null      string
#  3   date             6 non-null      string
#  4   time             6 non-null      string
#  5   timezone         6 non-null      Int64
#  6   user_id          6 non-null      Int64
#  7   username         6 non-null      string
#  8   name             6 non-null      string
#  9   place            0 non-null      Int64
#  10  tweet            6 non-null      string
#  11  language         6 non-null      string
#  12  mentions         6 non-null      string
#  13  urls             6 non-null      string
#  14  photos           6 non-null      string
#  15  replies_count    6 non-null      Int64
#  16  retweets_count   6 non-null      Int64
#  17  likes_count      6 non-null      Int64
#  18  hashtags         6 non-null      string
#  19  cashtags         6 non-null      string
#  20  link             6 non-null      string
#  21  retweet          6 non-null      boolean
#  22  quote_url        0 non-null      Int64
#  23  video            6 non-null      Int64
#  24  thumbnail        3 non-null      string
#  25  near             0 non-null      Int64
#  26  geo              0 non-null      Int64
#  27  source           0 non-null      Int64
#  28  user_rt_id       0 non-null      Int64
#  29  user_rt          0 non-null      Int64
#  30  retweet_id       0 non-null      Int64
#  31  reply_to         6 non-null      string
#  32  retweet_date     0 non-null      Int64
#  33  translate        0 non-null      Int64
#  34  trans_src        0 non-null      Int64
#  35  trans_dest       0 non-null      Int64
# dtypes: Int64(20), boolean(1), string(15)
# memory usage: 1.9 KB

# %%
# Try converting DataFrame.Series/columns to more specific types

tweets_df = tweets_df.convert_dtypes()
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               6 non-null      Int64
#  1   conversation_id  6 non-null      Int64
#  2   created_at       6 non-null      string
#  3   date             6 non-null      string
#  4   time             6 non-null      string
#  5   timezone         6 non-null      Int64
#  6   user_id          6 non-null      Int64
#  7   username         6 non-null      string
#  8   name             6 non-null      string
#  9   place            0 non-null      Int64
#  10  tweet            6 non-null      string
#  11  language         6 non-null      string
#  12  mentions         6 non-null      string
#  13  urls             6 non-null      string
#  14  photos           6 non-null      string
#  15  replies_count    6 non-null      Int64
#  16  retweets_count   6 non-null      Int64
#  17  likes_count      6 non-null      Int64
#  18  hashtags         6 non-null      string
#  19  cashtags         6 non-null      string
#  20  link             6 non-null      string
#  21  retweet          6 non-null      boolean
#  22  quote_url        0 non-null      Int64
#  23  video            6 non-null      Int64
#  24  thumbnail        3 non-null      string
#  25  near             0 non-null      Int64
#  26  geo              0 non-null      Int64
#  27  source           0 non-null      Int64
#  28  user_rt_id       0 non-null      Int64
#  29  user_rt          0 non-null      Int64
#  30  retweet_id       0 non-null      Int64
#  31  reply_to         6 non-null      string
#  32  retweet_date     0 non-null      Int64
#  33  translate        0 non-null      Int64
#  34  trans_src        0 non-null      Int64
#  35  trans_dest       0 non-null      Int64
# dtypes: Int64(20), boolean(1), string(15)
# memory usage: 1.9 KB

# %%
tweets_df.head()
# Out:
#                     id      conversation_id  ... trans_src trans_dest
# 0  1324469173297303552  1324469173297303552  ...      <NA>       <NA>
# 1  1324066382846320641  1324066382846320641  ...      <NA>       <NA>
# 2  1323013947973197824  1323013947973197824  ...      <NA>       <NA>
# 3  1062845234663563266  1062845234663563266  ...      <NA>       <NA>
# 4  1060999395653640192  1060999395653640192  ...      <NA>       <NA>
#
# [5 rows x 36 columns]

# %%
# how many tweets have a non-null URL field?

# len(tweets_df[tweets_df['quote_url'].str.len() > 0])

# %% [markdown]
# # **2. Aggregate your twitter datasets from all your searches and write to file (including a manifest file)**

# %%
# !ls tweets_twint*
# Out:
# tweets_twint_donald_trump__20201201-012233.csv
# tweets_twint_election_win__20201201-012219.csv
# tweets_twint_future__20201201-012121.csv
# tweets_twint_vote_court__20201201-012309.csv

# %%
# CUSTOMIZE: Define a RegEx pattern that matches all the twitter dataset files 
#            you want to combine (e.g. tweets_twint_*.csv)

tweet_filenames = 'tweets_twint_*.csv'  # Define the RegEx that matches all your twitter dataset files

all_tweet_files = [i for i in glob.glob(tweet_filenames)] # You should use 'tweets_*.csv'
print(all_tweet_files)
# Out:
# ['tweets_twint_future__20201201-012121.csv', 'tweets_twint_election_win__20201201-012219.csv', 'tweets_twint_donald_trump__20201201-012233.csv', 'tweets_twint_vote_court__20201201-012309.csv']

# %%
# Review user/search terms used to create these files

search_terms_ls
# Out:
# ['USERNAME:joebiden and SEARCHTERMS:future',
#  'USERNAME:joebiden and SEARCHTERMS:election win',
#  'USERNAME:joebiden and SEARCHTERMS:donald trump',
#  'USERNAME:joebiden and SEARCHTERMS:vote court']

# %%
# Combine all twitter dataset files into one pd.DataFrame
combined_df = pd.concat([pd.read_csv(f) for f in all_tweet_files ])

# Create a filename of search results in a file with the name contained a unique timestamp
timestr = time.strftime("%Y%m%d-%H%M%S")
file_name_combo = f"tweets_combined_{timestr}.csv"

# Write all tweets combined into one big file
combined_df.to_csv(file_name_combo, index=False, encoding='utf-8-sig')

# Write an accompnaying manifest file with all the search terms used to gather tweets in the combined file
file_name_combo_root = file_name_combo.split('.')[0]
file_name_combo_manifest = f"{file_name_combo_root}_manifest.txt"
with open(file_name_combo_manifest, 'w') as fp:
  fp.writelines(search_terms_ls)

# %%
# CONFIRM: Both the 'tweets_combined_*.csv' and 'tweets_combined_*_manifest.txt' files exist
#          and that the size of the combined dataset file is approximately equal to all the 
#          individual dataset files that went into it

# !ls -al tweets_*
# Out:
# -rw------- 1 root root 510389 Dec  1 01:24 tweets_combined_20201201-012404.csv
# -rw------- 1 root root    176 Dec  1 01:24 tweets_combined_20201201-012404_manifest.txt
# -rw------- 1 root root 883291 Nov 20 13:22 tweets_seattle_all.csv
# -rw------- 1 root root 397295 Dec  1 01:22 tweets_twint_donald_trump__20201201-012233.csv
# -rw------- 1 root root   7826 Dec  1 01:22 tweets_twint_election_win__20201201-012219.csv
# -rw------- 1 root root 106021 Dec  1 01:21 tweets_twint_future__20201201-012121.csv
# -rw------- 1 root root   5478 Dec  1 01:23 tweets_twint_vote_court__20201201-012309.csv

# %%
# CHECK: Make sure the manifest.txt file associated with our combined tweet dataset file saved all our
#        search terms

# type in the full filename of the most recent '*_manisfest.txt' file listed in the previous code cell above

# !cat tweets_combined_20201201-012404_manifest.txt
# Out:
# USERNAME:joebiden and SEARCHTERMS:futureUSERNAME:joebiden and SEARCHTERMS:election winUSERNAME:joebiden and SEARCHTERMS:donald trumpUSERNAME:joebiden and SEARCHTERMS:vote court

# %%
combined_df = combined_df.convert_dtypes()
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1060 entries, 0 to 9
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1060 non-null   Int64
#  1   conversation_id  1060 non-null   Int64
#  2   created_at       1060 non-null   string
#  3   date             1060 non-null   string
#  4   time             1060 non-null   string
#  5   timezone         1060 non-null   Int64
#  6   user_id          1060 non-null   Int64
#  7   username         1060 non-null   string
#  8   name             1060 non-null   string
#  9   place            0 non-null      Int64
#  10  tweet            1060 non-null   string
#  11  language         1060 non-null   string
#  12  mentions         1060 non-null   string
#  13  urls             1060 non-null   string
#  14  photos           1060 non-null   string
#  15  replies_count    1060 non-null   Int64
#  16  retweets_count   1060 non-null   Int64
#  17  likes_count      1060 non-null   Int64
#  18  hashtags         1060 non-null   string
#  19  cashtags         1060 non-null   string
#  20  link             1060 non-null   string
#  21  retweet          1060 non-null   boolean
#  22  quote_url        122 non-null    string
#  23  video            1060 non-null   Int64
#  24  thumbnail        335 non-null    string
#  25  near             0 non-null      Int64
#  26  geo              0 non-null      Int64
#  27  source           0 non-null      Int64
#  28  user_rt_id       0 non-null      Int64
#  29  user_rt          0 non-null      Int64
#  30  retweet_id       0 non-null      Int64
#  31  reply_to         1060 non-null   string
#  32  retweet_date     0 non-null      Int64
#  33  translate        0 non-null      Int64
#  34  trans_src        0 non-null      Int64
#  35  trans_dest       0 non-null      Int64
# dtypes: Int64(19), boolean(1), string(16)
# memory usage: 319.9 KB

# %% [markdown]
# # **3. Clean tweets and separate out subcomponents (e.g. hashtags, emojis, etc)**

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA) and Visualizations of Raw Data**
